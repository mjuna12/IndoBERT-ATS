# %%
# %%capture
# !pip install rouge_score
# !pip install datasets
# !pip install transformers
! pip install dill==0.3.6
import datasets
import transformers

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd 
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import transformers
from transformers import BertTokenizerFast, TFEncoderDecoderModel, AdamWeightDecay
from sklearn.model_selection import train_test_split

from tqdm.notebook import tqdm
from tensorflow.python.ops.numpy_ops import np_config
from pprint import pprint
""
# enable model saving at eager mode
np_config.enable_numpy_behavior()
print('transformers version:', transformers.__version__)
print('tensorflow version:', tf.__version__)
# Out:
# transformers version: 4.25.1
# tensorflow version: 2.9.2

# %%
df_reviews=pd.read_csv("/content/Experiment1.csv")
df_reviews.head()
# Out:
#    Unnamed: 0                                         paragraphs  \
# 0           0  jakarta cnn indonesia dokter ryan thamrin kena...
# 1           1  selfie ialah salah satu tema panas kalang prod...
# 2           2  jakarta cnn indonesia dinas pariwisata provins...
# 3           3  merdeka com indonesia corruption watch icw min...
# 4           4  merdeka com presiden joko widodo jokowi pimpin...
#
#                                              summary
# 0  dokter lula kamal yang merupakan selebriti sek...
# 1  asus memperkenalkan zenfone generasi keempat d...
# 2  dinas pariwisata provinsi bengkulu kembali men...
# 3  indonesia corruption watch icw meminta komisi ...
# 4  jokowi memimpin upacara penurunan bendera usai...

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14262 entries, 0 to 14261
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  14262 non-null  int64
#  1   paragraphs  14262 non-null  object
#  2   summary     14262 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 334.4+ KB

# %%
import nltk #import library nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize #import word_tokenize for tokenizing text into words 
#word tokenization
def word_tokenization(s):
    tokens = word_tokenize(s)
    return tokens

df_reviews['paragraphs'] = df_reviews['paragraphs'].apply(word_tokenization).apply(str)
pd.DataFrame(df_reviews['paragraphs'])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#                                               paragraphs
# 0      ['jakarta', 'cnn', 'indonesia', 'dokter', 'rya...
# 1      ['selfie', 'ialah', 'salah', 'satu', 'tema', '...
# 2      ['jakarta', 'cnn', 'indonesia', 'dinas', 'pari...
# 3      ['merdeka', 'com', 'indonesia', 'corruption', ...
# 4      ['merdeka', 'com', 'presiden', 'joko', 'widodo...
# ...                                                  ...
# 14257  ['jakarta', 'cnn', 'indonesia', 'amerika', 'se...
# 14258  ['bandung', 'cnn', 'indonesia', 'borneo', 'fc'...
# 14259  ['jakarta', 'pos', 'kota', 'a', 'komisi', 'ber...
# 14260  ['merdeka', 'com', 'buah', 'kabar', 'gembira',...
# 14261  ['satu', 'perangkat', 'tarik', 'saji', 'suguh'...
#
# [14262 rows x 1 columns]

# %%
df_reviews.to_pickle('df.pkl')

# %%
df_reviews = pd.read_pickle('df.pkl')
df_reviews_sampled = df_reviews.copy()
# sampling n pairs of reviews and summarizies on shuffled dataframe
df_reviews_sampled = df_reviews_sampled.iloc[:40000, :]
df_reviews_sampled['text_len'] = df_reviews_sampled['paragraphs'].apply(lambda x: len(x.split()))
df_reviews_sampled['summary_len'] = df_reviews_sampled['summary'].apply(lambda x: len(x.split()))
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16,5))
ax[0].hist(df_reviews_sampled['text_len'])
ax[0].set_xticks(np.arange(0, max(df_reviews_sampled['text_len'])+1,250))
ax[0].set_title('Histogram of length of tokenized text')
ax[1].hist(df_reviews_sampled['summary_len'], color='yellow')
ax[1].set_xticks(np.arange(0, max(df_reviews_sampled['summary_len'])+1,5))
ax[1].set_title('Histogram of length of tokenized summary')
# Out:
# Text(0.5, 1.0, 'Histogram of length of tokenized summary')

# %%
class TrainingConfig:
    from_pt=True 
    val_split = 0.2
    pretrained_checkpoint = 'indolem/indobert-base-uncased'
    encoder_checkpoint = 'indolem/indobert-base-uncased'
    decoder_checkpoint = 'indolem/indobert-base-uncased'
    pad_token_id = 0
    shared_weight = False
    encoder_max_len = 256 
    decoder_max_len = 30 
    nb_epoch = 7 
    learning_rate = 3e-5 
    batch_size = 16
    
    
    def __init__(self, **kwargs):
        for k,v in kwargs.items():
            setattr(self, k, v)

# %%
class DataLoader:
    def __init__(self, paragraphs, summaries, **kwargs):
        self.paragraphs = paragraphs 
        self.summaries = summaries 
        self.tokenizer = kwargs.get('tokenizer')
        self.val_split = kwargs.get('val_split')
        self.encoder_max_len = kwargs.get('encoder_max_len')
        self.decoder_max_len = kwargs.get('decoder_max_len')
    
    @property
    def sample_size(self):
        assert len(self.paragraphs)==len(self.summaries)
        return len(self.paragraphs)
    
    def split_train_test(self):
        train_idx, val_idx = train_test_split(
            list(range(self.sample_size)), 
            test_size=self.val_split, 
            random_state=98
        )
        return train_idx, val_idx
    
    def convert_text_to_ids(self, input_paragraphs, input_summaries):
        inputs = self.tokenizer(
            list(input_paragraphs), 
            return_tensors='np', 
            padding='max_length', 
            truncation=True, 
            max_length=self.encoder_max_len
        )
        outputs = self.tokenizer(
            list(input_summaries), 
            return_tensors='np', 
            padding='max_length', 
            truncation=True, 
            max_length=self.decoder_max_len
        )
        return inputs, outputs
    
    def list_to_tensor_dataset(self, input_paragraphs, input_summaries):
        inputs, outputs = self.convert_text_to_ids(
            input_paragraphs, 
            input_summaries
        )
        input_ids = tf.data.Dataset.from_tensor_slices(
            inputs['input_ids']
        )
        attention_masks = tf.data.Dataset.from_tensor_slices(
            inputs['attention_mask']
        )
        output_ids = tf.data.Dataset.from_tensor_slices(
            outputs['input_ids']
        )
        output_attention_masks = tf.data.Dataset.from_tensor_slices(
            outputs['attention_mask']
        )                                                
        tf_dataset = tf.data.Dataset.zip(
            ({
                'input_ids': input_ids, 
                'attention_mask': attention_masks,
                'decoder_input_ids': output_ids, 
                 'decoder_attention_mask': output_attention_masks
            }, 
            output_ids)
        )
        return tf_dataset
    
    def __call__(self):
        train_idx, val_idx = self.split_train_test()
        train_paras, val_paras = self.paragraphs[train_idx], self.paragraphs[val_idx]
        train_sums, val_sums = self.summaries[train_idx], self.summaries[val_idx]
        train_dataset = self.list_to_tensor_dataset(train_paras, train_sums)
        val_dataset = self.list_to_tensor_dataset(val_paras, val_sums)
        return train_dataset, val_dataset

# %%
class Seq2SeqLoss(tf.keras.losses.Loss):
    def __init__(self, pad_token_id, name="seq2seq_loss"):
        super().__init__(name=name)
        self.pad_token_id = pad_token_id

    def call(self, y_true, y_pred):
        loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(
            from_logits=True, 
            reduction=tf.keras.losses.Reduction.NONE
        )
        # shift the label and output sequences to match  
        output_logits = y_pred[:,:-1,:]
        input_labels = y_true[:,1:] 
        loss = loss_fn(input_labels, output_logits)
        # calculate loss without the padding tokens in label sequence
        mask = tf.cast((input_labels != self.pad_token_id), dtype=tf.float32)
        loss = loss * mask
        return tf.reduce_sum(loss) / tf.reduce_sum(mask)

# %%
class Trainer:
    def __init__(self, model, loss_fn, optimizer, metric):
        self.model = model
        self.loss_fn = loss_fn
        self.optimizer = optimizer
        self.metric = metric
        # loss tracker will capture the mean of loss till now
        self.loss_tracker = tf.keras.metrics.Mean(name='mean_loss')
    
    # Training Step
    @tf.function 
    def train_step(self, inputs):
        input_seqs, input_labels = inputs
        with tf.GradientTape() as tape: 
            outputs = self.model(
                input_seqs['input_ids'],
                input_seqs['attention_mask'],
                input_seqs['decoder_input_ids'],
                input_seqs['decoder_attention_mask'],
                training = True
            )
            logits = outputs.logits
            loss = self.loss_fn(input_labels, logits)
        gradients = tape.gradient(loss, self.model.trainable_weights)
        self.optimizer.apply_gradients(
            zip(gradients, self.model.trainable_weights)
        )
        self.loss_tracker.update_state(loss)
#         self.metric.update_state(y, predictions)
        return loss
        
    # Validation Step
    @tf.function  
    def val_step(self, inputs):
        input_seqs, input_labels = inputs
        outputs = self.model(                
                input_seqs['input_ids'],
                input_seqs['attention_mask'],
                input_seqs['decoder_input_ids'],
                input_seqs['decoder_attention_mask'],
                training = False
        )
        logits = outputs.logits
        loss = self.loss_fn(input_labels, logits)
        self.loss_tracker.update_state(loss)
#         self.metric.update_state(y,predictions)
        return loss

# %%
def batched_generate_summary(model, tokenizer, batched_input):
    input_seqs, input_labels = batched_input
    outputs = model.generate(
        input_ids=input_seqs['input_ids'], 
        attention_mask=input_seqs['attention_mask']
    )
    output_strs = tokenizer.batch_decode(
        outputs, 
        skip_special_tokens=True
    )
    output_gold = tokenizer.batch_decode(
        input_seqs['decoder_input_ids'], 
        skip_special_tokens=True
    )
    input_strs = tokenizer.batch_decode(
        input_seqs['input_ids'], 
        skip_special_tokens=True
    )
    return output_strs, output_gold, input_strs

# %%
reviews = df_reviews_sampled['paragraphs'].values
summaries = df_reviews_sampled['summary'].values

training_config = TrainingConfig(nb_epoch=7)
tokenizer = BertTokenizerFast.from_pretrained(training_config.encoder_checkpoint)

dataloader_args = {
    'tokenizer': tokenizer,
    'val_split': training_config.val_split,
    'encoder_max_len': training_config.encoder_max_len,
    'decoder_max_len': training_config.decoder_max_len
}
dataloader = DataLoader(reviews, summaries, **dataloader_args)
train_dataset, val_dataset = dataloader()
train_dataset = (train_dataset
                 .shuffle(int(dataloader.sample_size*(1-training_config.val_split)))
                 .batch(training_config.batch_size))
val_dataset = val_dataset.batch(training_config.batch_size)
# Out:
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/234k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.01k [00:00<?, ?B/s]

# %%
model = transformers.EncoderDecoderModel.from_encoder_decoder_pretrained(
    training_config.encoder_checkpoint, 
    training_config.decoder_checkpoint,
    tie_encoder_decoder=training_config.shared_weight,from_pt=True)
# Out:
# Downloading:   0%|          | 0.00/445M [00:00<?, ?B/s]

# %%
model.save_pretrained('indolem/indobert-base-uncased')
model = TFEncoderDecoderModel.from_pretrained('/content/indolem/indobert-base-uncased',from_pt=True)

# %%
model.config.decoder_start_token_id = tokenizer.cls_token_id # 101
model.config.eos_token_id = tokenizer.sep_token_id # 102 
model.config.pad_token_id = tokenizer.pad_token_id # 0
model.config.vocab_size = model.config.encoder.vocab_size

# %%
model.config.max_length = 30
model.config.min_length = 3
model.config.no_repeat_ngram_size = 2
model.config.early_stopping = True
model.config.length_penalty = 2.0
model.config.num_beams = 4

# %%
#rouge = datasets.load_metric('rouge')
tf.keras.backend.clear_session()
trainer = Trainer(model=model,
                  loss_fn=Seq2SeqLoss(training_config.pad_token_id),
                  optimizer=AdamWeightDecay(
                      learning_rate=training_config.learning_rate, 
                      weight_decay_rate=0.005),
                  metric=None)

# %%
import datasets
rouge = datasets.load_metric("rouge")
for epoch in range(training_config.nb_epoch):
    print(f'\nEpoch {epoch+1}\n')
    print('Training....')
    for step,batched_input in enumerate(tqdm(train_dataset)):
        loss = trainer.train_step(batched_input)
        till_now_loss = trainer.loss_tracker.result()
        if step%200 == 0:
            print(f'Training loss for one batch at step {step}: {round(till_now_loss,3)}') 
    trainer.loss_tracker.reset_states()
    print('Validating....')
    val_measures = {'rouge precision':0, 'rouge recall':0, 'rouge f1': 0}
    for step, batched_input in enumerate(tqdm(val_dataset)):
        val_loss = trainer.val_step(batched_input)
    till_now_val_loss = trainer.loss_tracker.result()
    print(f'Validation loss: {round(till_now_val_loss,3)}')
    model.save_pretrained(
        f'bert2bert-Checkpoint-epoch{epoch+1}-loss{round(till_now_val_loss,3)}'
    )
    trainer.loss_tracker.reset_states()
# Out:
# <ipython-input-20-adafa7a0519c>:2: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   rouge = datasets.load_metric("rouge")
# Downloading builder script:   0%|          | 0.00/2.16k [00:00<?, ?B/s]
# Epoch 1
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# WARNING:tensorflow:Gradients do not exist for variables ['tf_encoder_decoder_model/encoder/bert/pooler/dense/kernel:0', 'tf_encoder_decoder_model/encoder/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_encoder_decoder_model/encoder/bert/pooler/dense/kernel:0', 'tf_encoder_decoder_model/encoder/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# Training loss for one batch at step 0: 13.21500015258789
# Training loss for one batch at step 200: 8.062000274658203
# Training loss for one batch at step 400: 7.179999828338623
# Training loss for one batch at step 600: 6.604000091552734
# WARNING:tensorflow:Gradients do not exist for variables ['tf_encoder_decoder_model/encoder/bert/pooler/dense/kernel:0', 'tf_encoder_decoder_model/encoder/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 4.686999797821045
#
# Epoch 2
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 5.257999897003174
# Training loss for one batch at step 200: 4.736999988555908
# Training loss for one batch at step 400: 4.629000186920166
# Training loss for one batch at step 600: 4.556000232696533
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 4.103000164031982
#
# Epoch 3
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 4.265999794006348
# Training loss for one batch at step 200: 3.890000104904175
# Training loss for one batch at step 400: 3.8429999351501465
# Training loss for one batch at step 600: 3.812999963760376
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 3.7090001106262207
#
# Epoch 4
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 2.9619998931884766
# Training loss for one batch at step 200: 3.2679998874664307
# Training loss for one batch at step 400: 3.2339999675750732
# Training loss for one batch at step 600: 3.191999912261963
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 3.3580000400543213
#
# Epoch 5
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 2.48799991607666
# Training loss for one batch at step 200: 2.6579999923706055
# Training loss for one batch at step 400: 2.6389999389648438
# Training loss for one batch at step 600: 2.624000072479248
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 2.996000051498413
#
# Epoch 6
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 1.9550000429153442
# Training loss for one batch at step 200: 2.1589999198913574
# Training loss for one batch at step 400: 2.135999917984009
# Training loss for one batch at step 600: 2.117000102996826
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 2.7869999408721924
#
# Epoch 7
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 1.809999942779541
# Training loss for one batch at step 200: 1.7280000448226929
# Training loss for one batch at step 400: 1.722000002861023
# Training loss for one batch at step 600: 1.7200000286102295
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 2.6610000133514404

# %%
# from transformers import 
import datasets
rouge = datasets.load_metric("rouge")
trained_bert2bert = TFEncoderDecoderModel.from_pretrained("/content/bert2bert-Checkpoint-epoch7-loss2.6610000133514404")

# val0 = list(val_dataset.as_numpy_iterator())[0]
for step, batched_input in enumerate(tqdm(val_dataset)):
    pred_str, gold_str, input_strs = batched_generate_summary(
        trained_bert2bert, 
        tokenizer, 
        batched_input
    )
    rouge_output = rouge.compute(
        predictions=pred_str,
        references=gold_str,
        rouge_types=["rouge1","rouge2","rougeL"]
    )
    print('Rouge report: ')
    print("ROUGE 1 SCORE: ",rouge_output['rouge1'].mid)
    print("ROUGE 2 SCORE: ",rouge_output['rouge2'].mid)
    print("ROUGE F SCORE: ",rouge_output['rougeL'].mid)
    for p_str,g_str,in_str in zip(pred_str, gold_str, input_strs):
        print('='*100)
        print('Review: ' + in_str)
        print('Summary: ' + g_str)
        print('Generated: ' + p_str)
    
    break
# Out:
#   0%|          | 0/179 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/transformers/generation/tf_utils.py:1800: UserWarning: Neither `max_length` nor `max_new_tokens` have been set, `max_length` will default to 30 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Rouge report:
# ROUGE 1 SCORE:  Score(precision=0.48967019695280567, recall=0.5187017919469292, fmeasure=0.5032044886564793)
# ROUGE 2 SCORE:  Score(precision=0.30610967127414496, recall=0.3228116281284187, fmeasure=0.3137925419413762)
# ROUGE F SCORE:  Score(precision=0.4570918770239422, recall=0.48497648226159384, fmeasure=0.46978152584365734)
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','direktur ','utama ','pt ','transjakarta ','budi ','kaliwono ','minta ','maaf ','langgan ','kait ','ganggu ','layan ','transjakarta ','beberapa ','koridor ','sebab ','aksi ','karyawan ','tuntut ','naik ','gaji ','tetap ','status ','karyawan ','tetap ','senin ','rasa ','salah ','langgan ','ganggu ','kata ','budi ','temu ','kantor ','kawasan ','cawang ','jakarta ','timur ','budi ','kata ','operasi ','ratus ','armada ','transjakarta ','menganggu ','aktivitas ','langgan ','pagi ','tadi ','ratus ','karyawan ','laku ','aksi ','turun ','tumpang ','jumlah ','halte ','aksi ','sebab
# Summary: direktur utama pt transjakarta budi kaliwono meminta maaf kepada pelanggan terkait gangguan pelayanan transjakarta di beberapa koridor yang disebabkan aksi karyawan menuntut kenaikan gaji dan penetapan status
# Generated: direktur utama pt transjakarta budi kaliwono meminta maaf kepada pelanggan terkait insiden mogok kerja di beberapa wilayah di jakarta menurutnya aksi mogok menuntut gaji karyawan yang belum
# ====================================================================================================
# Review: ['jakarta ','a ','putra ','venna ','melinda ','athalla ','naufal ','alami ','celaka ','jumat ','malam ','kawasan ','jagakarsa ','jakarta ','selatan ','mobil ','kendara ','adik ','verrell ','bramasta ','hancur ','beberapa ','kali ','tabrak ','tiang ','meski ','kendara ','kondiri ','ringsek ','untung ','athalla ','tak ','alami ','cedera ','serius ','sempat ','lari ','rumah ','sakit ','pondok ','indah ','athalla ','ungkap ','diri ','baik ','baik ','a ','jadi ','buat ','lebih ','syukur ','hadap ','apa ','punya ','dengan ','hidup ','makasih ','allah ','swt
# Summary: putra kedua venna melinda athalla naufal mengalami kecelakaan pada jumat malam di kawasan jagakarsa jakarta selatan mobil yang dikendarai
# Generated: putra venna melinda athalla naufal mengalami kecelakaan pada jumat malam di kawasan jagakarsa jakarta selatan mobil adik kandungnya menabrak tiang
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','tim ','kuasa ','hukum ','gnpf ','kapitra ','ampera ','sebut ','pentol ','front ','bela ','islam ','rizieq ','shihab ','malaysia ','kata ','rizieq ','malaysia ','beberapa ','hari ','usai ','laksana ','ibadah ','umrah ','arab ','saudi ','kapitra ','kata ','rizieq ','malaysia ','konsultasi ','disertasi ','studi ','malaysia ','sampai ','rizieq ','indonesia ','pekan ','depan ','meski ','disertasi ','selesai ','lagi ','malaysia ','sekarang ','sedang ','siap ','disertasi ','minggu ','depan ','pulang ','kata ','kapitra ','hubung ','jumat ','rizieq ','malaysia ','konfirmasi ','kepala ', '
# Summary: tim kuasa hukum gnpf kapitra ampera menyebut pentolan front pembela islam rizieq shihab saat ini berada di malaysia dia mengatakan keberadaan rizieq di
# Generated: tim kuasa hukum gerakan pembela islam kapitra ampera menyebut pentolan fpi rizieq shihab telah menemui rizieq beberapa hari sebelum pelaksanaan ibadah umrah di arab saudi
# ====================================================================================================
# Review: ['lewat ','main ','baru ','hitman ','io ','interactive ','tebus ','jumlah ','keliru ','arah ','desain ','hitman ','absolution ','sana ','developer ','gameplay ','sandbox ','ala ','blood ','money ','sila ','main ','eksplorasi ','sendiri ','cara ','baik ','selesai ','misi ','tak ','lupa ','suguh ','map ','tujuh ','kali ','lebih ','besar ','absolution ','hitman ','suguh ','lalu ','metode ','unik ','pertama ','kali ','franchise ','game ','lepas ','cara ','episodik ','konten ','tujuh ','episode ','masuk ','bonus ','rilis ','mulai ','bulan ','maret ','hingga ','desember ', '
# Summary: lewat permainan baru hitman io interactive menebus kekeliruan pada arahan desain hitman absolution developer mengembalikan gameplay sandbox ala blood money mempersilakan pemain
# Generated: payman inter inter milan telah menuntaskan sejumlah kesalahan dalam beberapa tahun terakhir salah satunya adalah dengan meluncurkan sebuah karakter baru bernama gameplay ala starcraft ala
# ====================================================================================================
# Review: ['merdeka ','com ','orang ','ahli ','cokelat ','asal ','swiss ','cipta ','batang ','cokelat ','klaim ','mampu ','atas ','nyeri ','haid ','tanya ','makan ','sederhana ','cokelat ','benar ','benar ','ringan ','rasa ','sakit ','menstruasi ','kadang ','begitu ','tak ','tahan ','lansir ','dailymail ','marc ','widmer ','klaim ','kalau ','cokelat ','batang ','frauenmond ','dia ','kreasi ','buat ','wanita ','sedang ','haid ','hindar ','nyeri ','kram ','perut ','cokelat ','racik ','bahan ','herbal ','gunung ','swiss ','kakao ','persen ','semua ','bahan ','guna ','klaim ','angkat '
# Summary: dilansir dailymail marc widmer seorang ahli cokelat asal swiss mengklaim kalau cokelat batangan frauenmond yang dia kreasikan bisa membuat wanita
# Generated: seorang ahli cokelat asal swiss menciptakan batang cokelat dengan klaim bahwa mereka mampu mengatasi rasa sakit tenggorokan dan sakit pinggang hal itu terbukti dengan cara sederhana dan sederhana
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','ketua ','komisi ','ix ','dpr ','ri ','dede ','yusuf ','macan ','effendi ','aku ','minta ','partai ','demokrat ','siap ','diri ','masuk ','bursa ','nama ','calon ','gubernur ','pilgub ','jawa ','barat ','pilgub ','dinamis ','minta ','partai ','siap ','diri ','keluarga ','masih ','lihat ','dulu ','memang ','sangat ','butuh ','rakyat ','jawa ','barat ','tidak ','ujar ','dede ','yusuf ','kutip ','bandung ','minggu ','dede ','kata ','partai ','demokrat ','beri ','tenggat ','waktu ','tiga ','bulan ','para ','kader ','milik ','niat ','ikut '
# Summary: ketua komisi ix dpr ri dede yusuf macan effendi mengaku telah diminta partai demokrat mempersiapkan diri untuk masuk dalam bursa nama calon gubernur dalam pilgub jawa barat
# Generated: ketua komisi ix dpr ri dede yusuf effendi mengaku diminta partai demokrat untuk masuk dalam bursa calon gubernur jawa barat pada pilgub jabar permintaan itu disampaikan ketua
# ====================================================================================================
# Review: ['singapura ','cnn ','indonesia ','cerita ','rakyat ','agam ','mitos ','masyarakat ','asia ','bukan ','baru ','akrab ','tangkap ','jumlah ','sutradara ','asia ','masuk ','joko ','anwar ','indonesia ','jadi ','buah ','serial ','televisi ','tajuk ','folklore ','joko ','anwar ','serial ','payung ','hbo ','asia ','gandeng ','sutradara ','asal ','singapura ','eric ','khoo ','sekaligus ','cipta ','seri ','sebut ','lalu ','ho ','yuhang ','malaysia ','lee ','sang ','woo ','korea ','selatan ','pen ','ek ','ratanaruang ','thailand ','takumi ','saitoh ','jepang ','folklore ','bakal ',
# Summary: cerita rakyat dan mitos bagi masyarakat asia digarap sejumlah sutradara termasuk joko anwar dari indonesia untuk menjadi sebuah serial bertajukfolklore selain joko anwar serial
# Generated: cerita rakyat indonesia bukan hanya ada di masyarakat asia tetapi juga ada beberapa aktor ternama yang juga menjadi bagian dalam sebuah serial televisi berjudul folklore indonesia
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','gabung ','produsen ','rokok ','putih ','indonesia ','gaprindo ','aku ','kecewa ','putus ','perintah ','kerek ','tarif ','pajak ','tambah ','nilai ','ppn ','hasil ','tembakau ','persen ','jadi ','persen ','ketua ','umum ','gaprindo ','muhaimin ','moeftie ','kata ','benar ','rencana ','naik ','tahu ','asosiasi ','sejak ','agustus ','lalu ','kala ','diskus ','badan ','bijak ','fiskal ','bkf ','menteri ','uang ','diskusi ','rumus ','naik ','tarif ','ppn ','hasil ','tembakau ','cara ','tahap ','tahun ','tahun ','persen ','jadi ','persen ','persen ',
# Summary: gabungan pengusaha rokok putih indonesia gaprindo mengaku kecewa dengan keputusan pemerintah yang mengerek tarif ppn hasil tembakau dari persen menjadi persen memang awalnya rencana kenaikan
# Generated: gabungan produsen rokok indonesia dan indonesia mengaku kecewa dengan keputusan pemerintah yang memangkas tarif untuk rokok hasil pungutan pajak hasil tembakau persen menjadi persen ketua umum gabungan gabungan
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','menteri ','hukum ','ham ','yasonna ','hamonangan ','laoly ','kata ','pihak ','tunggu ','undang ','badan ','legislasi ','dpr ','bicara ','revisi ','undang ','undang ','mpr ','dpr ','dpd ','dprd ','harap ','baleg ','dpr ','segera ','undang ','kemenkumham ','revisi ','uu ','cepat ','selesai ','a ','tunggu ','undang ','baleg ','kalau ','perlu ','segera ','a ','ujar ','yasonna ','kantor ','kemenkumham ','jakarta ','sabtu ','malam ','yasonna ','tunggu ','undang ','baleg ','pihak ','kirim ','surat ','soal ','lanjut ','revisi ','uu ',
# Summary: menkumham yasonna laoly mengatakan pihaknya menunggu undangan baleg dpr untuk membicarakan revisi undang undang dia berharap baleg dpr segera mengundang kemenkum
# Generated: menteri hukum dan ham yasonna laoly mengatakan pihaknya belum menerima draf badan legislasi dpr untuk bicara soal revisi undang undang yang akan segera masuk ke dalam
# ====================================================================================================
# Review: ['banyak ','kamera ','awas ','rumah ','kantor ','tingkat ','aman ','harga ','agam ','gantung ','canggih ','lengkap ','fiturnya ','lemah ','besar ','kamera ','cctv ','standar ','letak ','a ','titik ','butaa ','perangkat ','paut ','satu ','posisi ','solusi ','harus ','pakai ','lebih ','satu ','unit ','buah ','solusi ','inovatif ','tawar ','tim ','aevena ','ide ','adopsi ','perangkat ','spesialis ','videography ','udara ','drone ','buat ','bantu ','aman ','tempat ','tinggal ','mereka ','kenal ','aire ','drone ','sekaligus ','kamera ','awas ','rancang ','dapat ','terbang ','manuver
# Summary: sebuah solusi inovatif ditawarkan oleh tim aevena dengan ide yang diadopsi dari perangkat spesialis videography udara drone untuk membantu mengamankan tempat tinggal
# Generated: aeonea ide yang terinspirasi dari sebuah kamera genggam yang dirancang untuk membantu pengguna yang sedang menggunakan peralatan tersebut droneone juga dilengkapi kamera megapix
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','kim ','kardashian ','akhir ','pamer ','foto ','anak ','tiga ','chicago ','west ','senin ','kemarin ','kim ','unggah ','foto ','sama ','chicago ','instagram ','meski ','beri ','efek ','telinga ','hidung ','lucu ','rupa ','pertama ','kali ','publik ','lihat ','foto ','chicago ','kini ','usia ','enam ','minggu ','lahir ','ibu ','ganti ','bayi ','chicago ','sederhana ','kim ','tulis ','terang ','foto ','foto ','sang ','istri ','kanye ','west ','gendong ','chicago ','kena ','busana ','nada ','diri ','warna ','pastel ','chicago ', '
# Summary: kim kardashian akhirnya memamerkan foto anak ketiganya chicago west senin kemarin kim mengunggah fotonya bersama chicago ke instagram meski diberi pula efek telinga
# Generated: kim kardashian akhirnya memamerkan foto foto anak di chicago pada senin kemarin kim mengunggah foto bersama kim jonghyun di instagram meski
# ====================================================================================================
# Review: ['suara ','com ','calon ','gubernur ','jawa ','tengah ','nomor ','urut ','sudirman ','said ','pulang ','kampung ','tuju ','tanah ','lahir ','brebes ','lantar ','terjang ','banjir ','minggu ','sudirman ','unjung ','tempat ','tampung ','ungsi ','desa ','kecipir ','losari ','lihat ','sedia ','stok ','pangan ','ungsi ','meski ','menu ','ikan ','asin ','sambal ','tempe ','semangat ','warga ','tinggi ','tahan ','kata ','sudirman ','pasang ','cawagub ','jateng ','ida ','fauziyah ','susur ','lokasi ','banjir ','desa ','kecipir ','dialog ','warga ','bantu ','rawan ','beri ',
# Summary: calon gubernur jawa tengah nomor urut sudirman said pulang kampung menuju tanah kelahirannya brebes lantaran kembali diterjang banjir minggu pasangan cawagub jateng ida fauziyah ini
# Generated: calon gubernur jawa tengah sudirman said pulang kampung menuju tanah kelahirannya brebes lantaran berpamitan untuk membangun tanggul di brebes sudirman bertolak ke tempat penampungan pengungsi di
# ====================================================================================================
# Review: ['suara ','com ','bila ','tak ','segera ','selesai ','konflik ','urus ','tubuh ','partai ','hanura ','bakal ','dampak ','besar ','keikutsertaannya ','milu ','hanura ','ancam ','lolos ','verifikasi ','partai ','politik ','lantar ','jadi ','pecah ','urus ','kalau ','parpol ','sesuai ','siapa ','tum ','siapa ','sekjennya ','punya ','resiko ','akan ','bisa ','lolos ','verifikasi ','faktual ','kata ','mantan ','komisioner ','kpu ','hadar ','navis ','gumay ','warung ','daun ','cikini ','jakarta ','pusat ','sabtu ','kata ','partai ','hanura ','ikut ','atur ','tetap ','masuk ','soal ', '
# Summary: bila tak segera diselesaikan konflik kepengurusan di tubuh partai hanura bakal berdampak besar pada keikutsertaannya di pemilu sebab hanura bisa terancam tidak lolos verifikasi partai politik lantaran
# Generated: tak ada yang bisa dimungkiri konflik internal tubuh partai hanura bakal berdampak besar pada keikutsertaannya dalam pemilu hanura terancam lolos verifikasi partai lantaran kalah dalam verifikasi
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','kepala ','staf ','tni ','angkat ','udara ','ksau ','marsekal ','tni ','yuyu ','sutisna ','kata ','rencana ','beli ','pesawat ','tempur ','generasi ','sukhoi ','perintah ','rusia ','terus ','jalan ','sukhoi ','jalan ','pengaruh ','apa ','apa ','sesuai ','apa ','sampai ','panglima ','tni ','marsekal ','tni ','had ','tjahjanto ','kata ','yuyu ','usai ','rapat ','pimpin ','rapim ','tni ','angkat ','udara ','cilangkap ','jakarta ','timur ','jumat ','kutip ','ksau ','kata ','tanggap ','informasi ','tekan ','perintah ','amerika ','serikat ','indonesia ', '
# Summary: ksau marsekal tni yuyu sutisna mengatakan rencana pembelian pesawat tempur generasi sukhoi dari pemerintah rusia masih terus berjalan ksau mengatakan hal itu menanggapi
# Generated: kepala staf tni angkatan udara marsekal tni yuyu sutina mengatakan rencana pembelian pesawat tempur sukhoi dari pemerintah pemerintah akan terus berjalan sesuai dengan tuntutan tuntutan sukhoi
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','pt ','golden ','energy ','mes ','tbk ','gems ','kantong ','pinjam ','besar ','us ','juta ','pt ','bank ','mandiri ','tbk ','bmri ','mayoritas ','raih ','dana ','beri ','anak ','usaha ','pt ','borneo ','indobara ','bib ','sekretaris ','usaha ','golden ','energy ','sudin ','sh ','kata ','manajemen ','sunti ','dana ','segar ','borneo ','indobara ','besar ','us ','juta ','butuh ','belanja ','modal ','capital ','expenditure ','capex ','salah ','satu ','proyek ','usaha ','tuju ','bagai ','biaya ','capex ','bangun ','fasilitas '
# Summary: pt golden energy mines tbk gems mengantongi pinjaman sebesar us juta dari pt bank mandiri tbk bmri mayoritas raihan dana itu akan diberikan kepada anak
# Generated: pt golden energy tbk menyalurkan kredit pinjam sebesar us juta kepada pt bank mandiri tbk mayoritas dana anak perusahaan pt borneo express bibri ini mayoritas didapat dari
# ====================================================================================================
# Review: ['besar ','masyarakat ','indonesia ','tahu ','serial ','keluarga ','cemara ','populer ','era ','an ','jadi ','salah ','satu ','serial ','baik ','selalu ','para ','gemar ','serial ','keluarga ','tulis ','arswendo ','atmowiloto ','banyak ','jadi ','bagai ','panutan ','keluarga ','indonesia ','hidup ','keluarga ','baik ','atas ','dasar ','rumah ','produksi ','visinema ','pictures ','angkat ','konsep ','dasar ','cerita ','sebut ','medium ','lebih ','besar ','layar ','lebar ','anggia ','kharisma ','bagai ','salah ','satu ','produser ','film ','jelas ','alas ','tarik ','angkat ','kisah ','keluarga ',
# Summary: serial keluarga cemara yang populer di era an kini akan diangkat ke layar lebar karakter abah dan emak yang ikonik nantinya doperankan ringgo agus rahman
# Generated: sebagian besar masyarakat indonesia tahu bahwa serial keluarga cemara populer menjadi salah satu tema yang diangkat oleh keluarga besar di indonesia hal itu terlihat dari diangkatnya serial

# %%
df_reviews_test = pd.read_csv("/content/Test1.csv")
test_reviews = df_reviews_test['paragraphs'].values
test_sums = df_reviews_test['summary'].values

test_dataloader = DataLoader(test_reviews, test_sums, **dataloader_args)
test_dataset = test_dataloader.list_to_tensor_dataset(test_reviews, test_sums)
test_dataset = test_dataset.batch(training_config.batch_size)
pred_strs = []
gold_strs = []

for batched_input in tqdm(test_dataset):
    pred_str, gold_str, _ = batched_generate_summary(
        trained_bert2bert, 
        tokenizer, 
        batched_input
    )
    pred_strs.extend(pred_str)
    gold_strs.extend(gold_str)
    
rouge_output = rouge.compute(
    predictions=pred_strs,
    references=gold_strs,
    rouge_types=["rouge1","rouge2","rougeL"]
)
# Out:
#   0%|          | 0/236 [00:00<?, ?it/s]

# %%
print('Rouge report: ')
print("ROUGE 1 SCORE: ",rouge_output['rouge1'].mid)
print("ROUGE 2 SCORE: ",rouge_output['rouge2'].mid)
print("ROUGE F SCORE: ",rouge_output['rougeL'].mid)
# Out:
# Rouge report:
# ROUGE 1 SCORE:  Score(precision=0.1582285147442523, recall=0.15650003144529367, fmeasure=0.1569246253680556)
# ROUGE 2 SCORE:  Score(precision=0.033110840846499304, recall=0.03281626174473288, fmeasure=0.03288009730336287)
# ROUGE F SCORE:  Score(precision=0.12709965155369668, recall=0.12577361422044336, fmeasure=0.12606823992231028)

# %%
rouge_output
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.15548026683970434, recall=0.15391162229763788, fmeasure=0.15424853239022318), mid=Score(precision=0.1582285147442523, recall=0.15650003144529367, fmeasure=0.1569246253680556), high=Score(precision=0.1612872015389466, recall=0.15945838394278558, fmeasure=0.1598444022844966)),
#  'rouge2': AggregateScore(low=Score(precision=0.03145530069419329, recall=0.031165168425413683, fmeasure=0.03123231107094482), mid=Score(precision=0.033110840846499304, recall=0.03281626174473288, fmeasure=0.03288009730336287), high=Score(precision=0.03468141006515218, recall=0.034404603932989254, fmeasure=0.03442816877980009)),
#  'rougeL': AggregateScore(low=Score(precision=0.12475865160368568, recall=0.1235645305452666, fmeasure=0.12380926791621526), mid=Score(precision=0.12709965155369668, recall=0.12577361422044336, fmeasure=0.12606823992231028), high=Score(precision=0.12956116636175688, recall=0.128137876631147, fmeasure=0.12842122699459219))}

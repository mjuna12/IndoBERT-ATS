# %%
# %%capture
# !pip install rouge_score
# !pip install datasets
# !pip install transformers
! pip install dill==0.3.6
import datasets
import transformers

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd 
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import transformers
from transformers import BertTokenizerFast, TFEncoderDecoderModel, AdamWeightDecay
from sklearn.model_selection import train_test_split

from tqdm.notebook import tqdm
from tensorflow.python.ops.numpy_ops import np_config
from pprint import pprint
""
# enable model saving at eager mode
np_config.enable_numpy_behavior()
print('transformers version:', transformers.__version__)
print('tensorflow version:', tf.__version__)
# Out:
# transformers version: 4.25.1
# tensorflow version: 2.9.2

# %%
df_reviews=pd.read_csv("/content/Experiment13.csv")
df_reviews.head()
# Out:
#    Unnamed: 0                                         paragraphs  \
# 0           0  jakarta cnn indonesia dokter ryan thamrin terk...
# 1           1  selfie ialah salah satu tema terpanas kalangan...
# 2           2  jakarta cnn indonesia dinas pariwisata provins...
# 3           3  merdeka com indonesia corruption watch icw mem...
# 4           4  merdeka com presiden joko widodo jokowi memimp...
#
#                                              summary
# 0  dokter lula kamal yang merupakan selebriti sek...
# 1  asus memperkenalkan zenfone generasi keempat d...
# 2  dinas pariwisata provinsi bengkulu kembali men...
# 3  indonesia corruption watch icw meminta komisi ...
# 4  jokowi memimpin upacara penurunan bendera usai...

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14262 entries, 0 to 14261
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  14262 non-null  int64
#  1   paragraphs  14262 non-null  object
#  2   summary     14262 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 334.4+ KB

# %%
import nltk #import library nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize #import word_tokenize for tokenizing text into words 
#word tokenization
def word_tokenization(s):
    tokens = word_tokenize(s)
    return tokens

df_reviews['paragraphs'] = df_reviews['paragraphs'].apply(word_tokenization).apply(str)
pd.DataFrame(df_reviews['paragraphs'])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#                                               paragraphs
# 0      ['jakarta', 'cnn', 'indonesia', 'dokter', 'rya...
# 1      ['selfie', 'ialah', 'salah', 'satu', 'tema', '...
# 2      ['jakarta', 'cnn', 'indonesia', 'dinas', 'pari...
# 3      ['merdeka', 'com', 'indonesia', 'corruption', ...
# 4      ['merdeka', 'com', 'presiden', 'joko', 'widodo...
# ...                                                  ...
# 14257  ['jakarta', 'cnn', 'indonesia', 'amerika', 'se...
# 14258  ['bandung', 'cnn', 'indonesia', 'borneo', 'fc'...
# 14259  ['jakarta', 'pos', 'kota', 'a', 'komisi', 'pem...
# 14260  ['merdeka', 'com', 'sebuah', 'kabar', 'gembira...
# 14261  ['satu', 'perangkat', 'menarik', 'lainnya', 't...
#
# [14262 rows x 1 columns]

# %%
df_reviews.to_pickle('df.pkl')

# %%
df_reviews = pd.read_pickle('df.pkl')
df_reviews_sampled = df_reviews.copy()
# sampling n pairs of reviews and summarizies on shuffled dataframe
df_reviews_sampled = df_reviews_sampled.iloc[:40000, :]
df_reviews_sampled['text_len'] = df_reviews_sampled['paragraphs'].apply(lambda x: len(x.split()))
df_reviews_sampled['summary_len'] = df_reviews_sampled['summary'].apply(lambda x: len(x.split()))
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16,5))
ax[0].hist(df_reviews_sampled['text_len'])
ax[0].set_xticks(np.arange(0, max(df_reviews_sampled['text_len'])+1,250))
ax[0].set_title('Histogram of length of tokenized text')
ax[1].hist(df_reviews_sampled['summary_len'], color='yellow')
ax[1].set_xticks(np.arange(0, max(df_reviews_sampled['summary_len'])+1,5))
ax[1].set_title('Histogram of length of tokenized summary')
# Out:
# Text(0.5, 1.0, 'Histogram of length of tokenized summary')

# %%
class TrainingConfig:
    from_pt=True 
    val_split = 0.2
    pretrained_checkpoint = 'indolem/indobert-base-uncased'
    encoder_checkpoint = 'indolem/indobert-base-uncased'
    decoder_checkpoint = 'indolem/indobert-base-uncased'
    pad_token_id = 0
    shared_weight = False
    encoder_max_len = 256 
    decoder_max_len = 30 
    nb_epoch = 7 
    learning_rate = 3e-5 
    batch_size = 16
    
    
    def __init__(self, **kwargs):
        for k,v in kwargs.items():
            setattr(self, k, v)

# %%
class DataLoader:
    def __init__(self, paragraphs, summaries, **kwargs):
        self.paragraphs = paragraphs 
        self.summaries = summaries 
        self.tokenizer = kwargs.get('tokenizer')
        self.val_split = kwargs.get('val_split')
        self.encoder_max_len = kwargs.get('encoder_max_len')
        self.decoder_max_len = kwargs.get('decoder_max_len')
    
    @property
    def sample_size(self):
        assert len(self.paragraphs)==len(self.summaries)
        return len(self.paragraphs)
    
    def split_train_test(self):
        train_idx, val_idx = train_test_split(
            list(range(self.sample_size)), 
            test_size=self.val_split, 
            random_state=98
        )
        return train_idx, val_idx
    
    def convert_text_to_ids(self, input_paragraphs, input_summaries):
        inputs = self.tokenizer(
            list(input_paragraphs), 
            return_tensors='np', 
            padding='max_length', 
            truncation=True, 
            max_length=self.encoder_max_len
        )
        outputs = self.tokenizer(
            list(input_summaries), 
            return_tensors='np', 
            padding='max_length', 
            truncation=True, 
            max_length=self.decoder_max_len
        )
        return inputs, outputs
    
    def list_to_tensor_dataset(self, input_paragraphs, input_summaries):
        inputs, outputs = self.convert_text_to_ids(
            input_paragraphs, 
            input_summaries
        )
        input_ids = tf.data.Dataset.from_tensor_slices(
            inputs['input_ids']
        )
        attention_masks = tf.data.Dataset.from_tensor_slices(
            inputs['attention_mask']
        )
        output_ids = tf.data.Dataset.from_tensor_slices(
            outputs['input_ids']
        )
        output_attention_masks = tf.data.Dataset.from_tensor_slices(
            outputs['attention_mask']
        )                                                
        tf_dataset = tf.data.Dataset.zip(
            ({
                'input_ids': input_ids, 
                'attention_mask': attention_masks,
                'decoder_input_ids': output_ids, 
                 'decoder_attention_mask': output_attention_masks
            }, 
            output_ids)
        )
        return tf_dataset
    
    def __call__(self):
        train_idx, val_idx = self.split_train_test()
        train_paras, val_paras = self.paragraphs[train_idx], self.paragraphs[val_idx]
        train_sums, val_sums = self.summaries[train_idx], self.summaries[val_idx]
        train_dataset = self.list_to_tensor_dataset(train_paras, train_sums)
        val_dataset = self.list_to_tensor_dataset(val_paras, val_sums)
        return train_dataset, val_dataset

# %%
class Seq2SeqLoss(tf.keras.losses.Loss):
    def __init__(self, pad_token_id, name="seq2seq_loss"):
        super().__init__(name=name)
        self.pad_token_id = pad_token_id

    def call(self, y_true, y_pred):
        loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(
            from_logits=True, 
            reduction=tf.keras.losses.Reduction.NONE
        )
        # shift the label and output sequences to match  
        output_logits = y_pred[:,:-1,:]
        input_labels = y_true[:,1:] 
        loss = loss_fn(input_labels, output_logits)
        # calculate loss without the padding tokens in label sequence
        mask = tf.cast((input_labels != self.pad_token_id), dtype=tf.float32)
        loss = loss * mask
        return tf.reduce_sum(loss) / tf.reduce_sum(mask)

# %%
class Trainer:
    def __init__(self, model, loss_fn, optimizer, metric):
        self.model = model
        self.loss_fn = loss_fn
        self.optimizer = optimizer
        self.metric = metric
        # loss tracker will capture the mean of loss till now
        self.loss_tracker = tf.keras.metrics.Mean(name='mean_loss')
    
    # Training Step
    @tf.function 
    def train_step(self, inputs):
        input_seqs, input_labels = inputs
        with tf.GradientTape() as tape: 
            outputs = self.model(
                input_seqs['input_ids'],
                input_seqs['attention_mask'],
                input_seqs['decoder_input_ids'],
                input_seqs['decoder_attention_mask'],
                training = True
            )
            logits = outputs.logits
            loss = self.loss_fn(input_labels, logits)
        gradients = tape.gradient(loss, self.model.trainable_weights)
        self.optimizer.apply_gradients(
            zip(gradients, self.model.trainable_weights)
        )
        self.loss_tracker.update_state(loss)
#         self.metric.update_state(y, predictions)
        return loss
        
    # Validation Step
    @tf.function  
    def val_step(self, inputs):
        input_seqs, input_labels = inputs
        outputs = self.model(                
                input_seqs['input_ids'],
                input_seqs['attention_mask'],
                input_seqs['decoder_input_ids'],
                input_seqs['decoder_attention_mask'],
                training = False
        )
        logits = outputs.logits
        loss = self.loss_fn(input_labels, logits)
        self.loss_tracker.update_state(loss)
#         self.metric.update_state(y,predictions)
        return loss

# %%
def batched_generate_summary(model, tokenizer, batched_input):
    input_seqs, input_labels = batched_input
    outputs = model.generate(
        input_ids=input_seqs['input_ids'], 
        attention_mask=input_seqs['attention_mask']
    )
    output_strs = tokenizer.batch_decode(
        outputs, 
        skip_special_tokens=True
    )
    output_gold = tokenizer.batch_decode(
        input_seqs['decoder_input_ids'], 
        skip_special_tokens=True
    )
    input_strs = tokenizer.batch_decode(
        input_seqs['input_ids'], 
        skip_special_tokens=True
    )
    return output_strs, output_gold, input_strs

# %%
reviews = df_reviews_sampled['paragraphs'].values
summaries = df_reviews_sampled['summary'].values

training_config = TrainingConfig(nb_epoch=7)
tokenizer = BertTokenizerFast.from_pretrained(training_config.encoder_checkpoint)

dataloader_args = {
    'tokenizer': tokenizer,
    'val_split': training_config.val_split,
    'encoder_max_len': training_config.encoder_max_len,
    'decoder_max_len': training_config.decoder_max_len
}
dataloader = DataLoader(reviews, summaries, **dataloader_args)
train_dataset, val_dataset = dataloader()
train_dataset = (train_dataset
                 .shuffle(int(dataloader.sample_size*(1-training_config.val_split)))
                 .batch(training_config.batch_size))
val_dataset = val_dataset.batch(training_config.batch_size)
# Out:
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/234k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.01k [00:00<?, ?B/s]

# %%
model = transformers.EncoderDecoderModel.from_encoder_decoder_pretrained(
    training_config.encoder_checkpoint, 
    training_config.decoder_checkpoint,
    tie_encoder_decoder=training_config.shared_weight,from_pt=True)
# Out:
# Downloading:   0%|          | 0.00/445M [00:00<?, ?B/s]

# %%
model.save_pretrained('indolem/indobert-base-uncased')
model = TFEncoderDecoderModel.from_pretrained('/content/indolem/indobert-base-uncased',from_pt=True)

# %%
model.config.decoder_start_token_id = tokenizer.cls_token_id # 101
model.config.eos_token_id = tokenizer.sep_token_id # 102 
model.config.pad_token_id = tokenizer.pad_token_id # 0
model.config.vocab_size = model.config.encoder.vocab_size

# %%
model.config.max_length = 30
model.config.min_length = 3
model.config.no_repeat_ngram_size = 2
model.config.early_stopping = True
model.config.length_penalty = 2.0
model.config.num_beams = 4

# %%
#rouge = datasets.load_metric('rouge')
tf.keras.backend.clear_session()
trainer = Trainer(model=model,
                  loss_fn=Seq2SeqLoss(training_config.pad_token_id),
                  optimizer=AdamWeightDecay(
                      learning_rate=training_config.learning_rate, 
                      weight_decay_rate=0.005),
                  metric=None)

# %%
import datasets
rouge = datasets.load_metric("rouge")
for epoch in range(training_config.nb_epoch):
    print(f'\nEpoch {epoch+1}\n')
    print('Training....')
    for step,batched_input in enumerate(tqdm(train_dataset)):
        loss = trainer.train_step(batched_input)
        till_now_loss = trainer.loss_tracker.result()
        if step%200 == 0:
            print(f'Training loss for one batch at step {step}: {round(till_now_loss,3)}') 
    trainer.loss_tracker.reset_states()
    print('Validating....')
    val_measures = {'rouge precision':0, 'rouge recall':0, 'rouge f1': 0}
    for step, batched_input in enumerate(tqdm(val_dataset)):
        val_loss = trainer.val_step(batched_input)
    till_now_val_loss = trainer.loss_tracker.result()
    print(f'Validation loss: {round(till_now_val_loss,3)}')
    model.save_pretrained(
        f'bert2bert-Checkpoint-epoch{epoch+1}-loss{round(till_now_val_loss,3)}'
    )
    trainer.loss_tracker.reset_states()
# Out:
# <ipython-input-19-adafa7a0519c>:2: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   rouge = datasets.load_metric("rouge")
# Downloading builder script:   0%|          | 0.00/2.16k [00:00<?, ?B/s]
# Epoch 1
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# WARNING:tensorflow:Gradients do not exist for variables ['tf_encoder_decoder_model/encoder/bert/pooler/dense/kernel:0', 'tf_encoder_decoder_model/encoder/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_encoder_decoder_model/encoder/bert/pooler/dense/kernel:0', 'tf_encoder_decoder_model/encoder/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# Training loss for one batch at step 0: 14.149999618530273
# Training loss for one batch at step 200: 7.478000164031982
# Training loss for one batch at step 400: 6.651000022888184
# Training loss for one batch at step 600: 6.14900016784668
# WARNING:tensorflow:Gradients do not exist for variables ['tf_encoder_decoder_model/encoder/bert/pooler/dense/kernel:0', 'tf_encoder_decoder_model/encoder/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 4.4079999923706055
#
# Epoch 2
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 4.209000110626221
# Training loss for one batch at step 200: 4.376999855041504
# Training loss for one batch at step 400: 4.302999973297119
# Training loss for one batch at step 600: 4.230999946594238
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 3.8580000400543213
#
# Epoch 3
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 3.5910000801086426
# Training loss for one batch at step 200: 3.5810000896453857
# Training loss for one batch at step 400: 3.5480000972747803
# Training loss for one batch at step 600: 3.5269999504089355
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 3.561000108718872
#
# Epoch 4
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 3.0769999027252197
# Training loss for one batch at step 200: 2.9769999980926514
# Training loss for one batch at step 400: 2.9790000915527344
# Training loss for one batch at step 600: 2.9630000591278076
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 3.2760000228881836
#
# Epoch 5
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 2.197000026702881
# Training loss for one batch at step 200: 2.490999937057495
# Training loss for one batch at step 400: 2.447000026702881
# Training loss for one batch at step 600: 2.4260001182556152
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 2.9679999351501465
#
# Epoch 6
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 1.7209999561309814
# Training loss for one batch at step 200: 1.9630000591278076
# Training loss for one batch at step 400: 1.9509999752044678
# Training loss for one batch at step 600: 1.9329999685287476
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 2.7109999656677246
#
# Epoch 7
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 1.684999942779541
# Training loss for one batch at step 200: 1.5190000534057617
# Training loss for one batch at step 400: 1.527999997138977
# Training loss for one batch at step 600: 1.5210000276565552
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 2.5399999618530273

# %%
# from transformers import 
import datasets
rouge = datasets.load_metric("rouge")
trained_bert2bert = TFEncoderDecoderModel.from_pretrained("/content/bert2bert-Checkpoint-epoch7-loss2.5399999618530273")

# val0 = list(val_dataset.as_numpy_iterator())[0]
for step, batched_input in enumerate(tqdm(val_dataset)):
    pred_str, gold_str, input_strs = batched_generate_summary(
        trained_bert2bert, 
        tokenizer, 
        batched_input
    )
    rouge_output = rouge.compute(
        predictions=pred_str,
        references=gold_str,
        rouge_types=["rouge1","rouge2","rougeL"]
    )
    print('Rouge report: ')
    print("ROUGE 1 SCORE: ",rouge_output['rouge1'].mid)
    print("ROUGE 2 SCORE: ",rouge_output['rouge2'].mid)
    print("ROUGE F SCORE: ",rouge_output['rougeL'].mid)
    for p_str,g_str,in_str in zip(pred_str, gold_str, input_strs):
        print('='*100)
        print('Review: ' + in_str)
        print('Summary: ' + g_str)
        print('Generated: ' + p_str)
    
    break
# Out:
#   0%|          | 0/179 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/transformers/generation/tf_utils.py:1800: UserWarning: Neither `max_length` nor `max_new_tokens` have been set, `max_length` will default to 30 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Rouge report:
# ROUGE 1 SCORE:  Score(precision=0.5345889140046749, recall=0.5578670177447352, fmeasure=0.545328235888382)
# ROUGE 2 SCORE:  Score(precision=0.34318879037629035, recall=0.36196526962581027, fmeasure=0.35202083640643467)
# ROUGE F SCORE:  Score(precision=0.5119619518464628, recall=0.5370527773856578, fmeasure=0.5234872705463298)
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','direktur ','utama ','pt ','transjakarta ','budi ','kaliwono ','meminta ','maaf ','pelanggan ','terkait ','gangguan ','pelayanan ','transjakarta ','beberapa ','koridor ','disebabkan ','aksi ','karyawan ','menuntut ','kenaikan ','gaji ','penetapan ','status ','karyawan ','tetap ','senin ','merasa ','bersalah ','pelanggan ','adanya ','gangguan ','kata ','budi ','ditemui ','kantornya ','berada ','kawasan ','cawang ','jakarta ','timur ','budi ','mengatakan ','beroperasinya ','ratusan ','armada ','transjakarta ','menganggu ','aktivitas ','pelanggan ','pagi ','tadi ','ratusan ','karyawan ','melakukan ','aksi ','menurunkan ','penumpang ','sejumlah ','halte ','aksi '
# Summary: direktur utama pt transjakarta budi kaliwono meminta maaf kepada pelanggan terkait gangguan pelayanan transjakarta di beberapa koridor yang disebabkan aksi karyawan menuntut kenaikan gaji dan penetapan status
# Generated: direktur utama pt transjakarta budi kaliwono meminta maaf kepada pelanggan layanan transjakarta terkait aksi mogok karyawan yang dilakukan oleh karyawan untuk menuntut kenaikan gaji penetapan tarif penetapan
# ====================================================================================================
# Review: ['jakarta ','a ','putra ','kedua ','venna ','melinda ','athalla ','naufal ','mengalami ','kecelakaan ','jumat ','malam ','kawasan ','jagakarsa ','jakarta ','selatan ','mobil ','dikendarai ','adik ','verrell ','bramasta ','hancur ','beberapa ','kali ','menabrak ','tiang ','meski ','kendaraan ','kondiri ','ringsek ','beruntung ','athalla ','tak ','mengalami ','cedera ','serius ','sempat ','dilarikan ','rumah ','sakit ','pondok ','indah ','athalla ','mengungkapkan ','dirinya ','baik ','baik ','a ','kejadian ','membuat ','lebih ','bersyukur ','apa ','punya ','dengan ','hidup ','makasih ','allah ','swt ', '
# Summary: putra kedua venna melinda athalla naufal mengalami kecelakaan pada jumat malam di kawasan jagakarsa jakarta selatan mobil yang dikendarai
# Generated: putra kedua venna meliana athanasa mengalami kecelakaan pada jumat malam di kawasan jagakarsa jakarta selatan mobil yang dikendarai adik kandungnya itu
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','tim ','kuasa ','hukum ','gnpf ','kapitra ','ampera ','menyebut ','pentolan ','front ','pembela ','islam ','rizieq ','shihab ','berada ','malaysia ','mengatakan ','keberadaan ','rizieq ','malaysia ','beberapa ','hari ','usai ','melaksanakan ','ibadah ','umrah ','arab ','saudi ','kapitra ','mengatakan ','rizieq ','malaysia ','konsultasi ','disertasi ','studinya ','malaysia ','menyampaikan ','rizieq ','indonesia ','pekan ','depan ','meskipun ','disertasinya ','selesai ','lagi ','malaysia ','sekarang ','sedang ','menyiapkan ','disertasi ','minggu ','depan ','pulang ','kata ','kapitra ','dihubungi ','jumat ','keberadaan ','rizieq ', '
# Summary: tim kuasa hukum gnpf kapitra ampera menyebut pentolan front pembela islam rizieq shihab saat ini berada di malaysia dia mengatakan keberadaan rizieq di
# Generated: tim kuasa hukum gnpf kapitra ampera menyebut pentolan front pembela islam rizieq shihab yang berada di malaysia mengatakan keberadaan rizieq tidak ada kaitannya
# ====================================================================================================
# Review: ['lewat ','permainan ','baru ','hitman ','io ','interactive ','menebus ','sejumlah ','kekeliruan ','arahan ','desain ','hitman ','absolution ','sana ','developer ','mengembalikan ','gameplay ','sandbox ','ala ','blood ','money ','mempersilakan ','pemain ','bereksplorasi ','menentukan ','sendiri ','cara ','terbaik ','menyelesaikan ','misi ','tak ','lupa ','menyuguhkan ','map ','tujuh ','kali ','lebih ','besar ','absolution ','hitman ','disuguhkan ','melalui ','metode ','unik ','pertama ','kalinya ','franchise ','game ','dilepas ','episodik ','kontennya ','terbagi ','tujuh ','episode ','termasuk ','bonus ','dirilis ','mulai ','bulan ','maret ', '
# Summary: lewat permainan baru hitman io interactive menebus kekeliruan pada arahan desain hitman absolution developer mengembalikan gameplay sandbox ala blood money mempersilakan pemain
# Generated: hitfren kembali menebus sejumlah permainan hitman di sana dengan membenamkan sejumlah elemen desain yang kaya dengan konsep sandplace ala coldplay dan
# ====================================================================================================
# Review: ['merdeka ','com ','seorang ','ahli ','cokelat ','asal ','swiss ','menciptakan ','sebatang ','cokelat ','diklaim ','mampu ','mengatasi ','nyeri ','haid ','pertanyaannya ','makanan ','sesederhana ','cokelat ','benar ','benar ','meringankan ','rasa ','sakit ','menstruasi ','kadang ','begitu ','tak ','tertahankan ','dilansir ','dailymail ','marc ','widmer ','mengklaim ','kalau ','cokelat ','batangan ','frauenmond ','dia ','kreasikan ','membuat ','wanita ','sedang ','haid ','terhindar ','nyeri ','kram ','perut ','cokelat ','diraciknya ','bahan ','herbal ','pegunungan ','swiss ','kakao ','persen ','semua ','bahan ','digunakan ','diklaim
# Summary: dilansir dailymail marc widmer seorang ahli cokelat asal swiss mengklaim kalau cokelat batangan frauenmond yang dia kreasikan bisa membuat wanita
# Generated: seorang ahli cokelat asal swiss menciptakan sebuah strice cokelat yang diklaim mampu mengatasi nyeri haid dengan mudah mengatasi rasa sakit itu dengan cara sederhana dr clamer
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','ketua ','komisi ','ix ','dpr ','ri ','dede ','yusuf ','macan ','effendi ','mengaku ','diminta ','partai ','demokrat ','mempersiapkan ','diri ','masuk ','bursa ','nama ','calon ','gubernur ','pilgub ','jawa ','barat ','pilgub ','dinamis ','diminta ','partai ','mempersiapkan ','diri ','keluarga ','masih ','melihat ','dulu ','memang ','sangat ','dibutuhkan ','rakyat ','jawa ','barat ','tidak ','ujar ','dede ','yusuf ','dikutip ','bandung ','minggu ','dede ','mengatakan ','partai ','demokrat ','memberikan ','tenggat ','waktu ','tiga ','bulan ','para ','kader ','memiliki ','niat ','ikut '
# Summary: ketua komisi ix dpr ri dede yusuf macan effendi mengaku telah diminta partai demokrat mempersiapkan diri untuk masuk dalam bursa nama calon gubernur dalam pilgub jawa barat
# Generated: ketua komisi ix dpr ri dede yusuf mengaku diminta partai demokrat untuk mempersiapkan diri untuk masuk bursa calon gubernur pilgub jawa barat yang akan berlangsung di pilg
# ====================================================================================================
# Review: ['singapura ','cnn ','indonesia ','cerita ','rakyat ','beragam ','mitos ','masyarakat ','asia ','bukan ','baru ','keakraban ','ditangkap ','sejumlah ','sutradara ','asia ','termasuk ','joko ','anwar ','indonesia ','menjadi ','sebuah ','serial ','televisi ','bertajuk ','folklore ','joko ','anwar ','serial ','dipayungi ','hbo ','asia ','menggandeng ','sutradara ','asal ','singapura ','eric ','khoo ','sekaligus ','pencipta ','seri ','tersebut ','lalu ','ho ','yuhang ','malaysia ','lee ','sang ','woo ','korea ','selatan ','pen ','ek ','ratanaruang ','thailand ','takumi ','saitoh ','jepang ','folklore ', '
# Summary: cerita rakyat dan mitos bagi masyarakat asia digarap sejumlah sutradara termasuk joko anwar dari indonesia untuk menjadi sebuah serial bertajukfolklore selain joko anwar serial
# Generated: cerita rakyat yang beragam dari masyarakat asia bukan hanya berasal dari sejumlah aktor asia yang menjadi serial televisi jokowi menjadi viral di kalangan folklore jokowi
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','gabungan ','produsen ','rokok ','putih ','indonesia ','gaprindo ','mengaku ','kecewa ','keputusan ','pemerintah ','mengerek ','tarif ','pajak ','pertambahan ','nilai ','ppn ','hasil ','tembakau ','persen ','menjadi ','persen ','ketua ','umum ','gaprindo ','muhaimin ','moeftie ','mengatakan ','sebenarnya ','rencana ','kenaikan ','diketahui ','asosiasi ','sejak ','agustus ','lalu ','kala ','berdiskusi ','badan ','kebijakan ','fiskal ','bkf ','kementerian ','keuangan ','diskusi ','merumuskan ','kenaikan ','tarif ','ppn ','hasil ','tembakau ','bertahap ','tahun ','tahun ','persen ','menjadi ','persen ','persen ','sayangkan ',
# Summary: gabungan pengusaha rokok putih indonesia gaprindo mengaku kecewa dengan keputusan pemerintah yang mengerek tarif ppn hasil tembakau dari persen menjadi persen memang awalnya rencana kenaikan
# Generated: gabungan produsen rokok di indonesia mengaku kecewa dengan keputusan pemerintah yang mengerucut pada tarif pemungutan cukai hasil pemungutan suara persen ketua bidang komunikasi merah indonesia tonny
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','menteri ','hukum ','ham ','yasonna ','hamonangan ','laoly ','mengatakan ','pihaknya ','menunggu ','undangan ','badan ','legislasi ','dpr ','membicarakan ','revisi ','undang ','undang ','mpr ','dpr ','dpd ','dprd ','berharap ','baleg ','dpr ','segera ','mengundang ','kemenkumham ','revisi ','uu ','cepat ','diselesaikan ','a ','tunggu ','undangan ','baleg ','kalau ','perlu ','segera ','a ','ujar ','yasonna ','kantor ','kemenkumham ','jakarta ','sabtu ','malam ','yasonna ','menunggu ','undangan ','baleg ','pihaknya ','berkirim ','surat ','soal ','kelanjutan ','revisi ','uu '
# Summary: menkumham yasonna laoly mengatakan pihaknya menunggu undangan baleg dpr untuk membicarakan revisi undang undang dia berharap baleg dpr segera mengundang kemenkum
# Generated: menteri hukum dan hak asasi manusia yasonna laoly mengatakan pihaknya menunggu kedatangan badan legislasi dpr untuk membicarakan revisi undang undang nomor tahun tentang mpr ke dpr
# ====================================================================================================
# Review: ['banyak ','kamera ','pengawas ','gunakan ','rumah ','kantor ','meningkatkan ','keamanan ','harganya ','beragam ','tergantung ','kecanggihan ','kelengkapan ','fiturnya ','kelemahan ','terbesar ','kamera ','cctv ','standar ','terletak ','a ','titik ','butaa ','perangkat ','terpaut ','satu ','posisi ','solusinya ','harus ','memakai ','lebih ','satu ','unit ','sebuah ','solusi ','inovatif ','ditawarkan ','tim ','aevena ','ide ','diadopsi ','perangkat ','spesialis ','videography ','udara ','drone ','buat ','membantu ','mengamankan ','tempat ','tinggal ','mereka ','memperkenalkan ','aire ','drone ','sekaligus ','kamera ','pengawas ','dirancang ','dapat ', '
# Summary: sebuah solusi inovatif ditawarkan oleh tim aevena dengan ide yang diadopsi dari perangkat spesialis videography udara drone untuk membantu mengamankan tempat tinggal
# Generated: tim pengawas aesca yang dirancang untuk membantu pengguna untuk menemukan titik titik yang terletak di sekitar rumah drone ini merancang kamera yang dapat mendeteksi titik
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','kim ','kardashian ','akhirnya ','memamerkan ','foto ','anak ','ketiganya ','chicago ','west ','senin ','kemarin ','kim ','mengunggah ','fotonya ','bersama ','chicago ','instagram ','meski ','diberi ','efek ','telinga ','hidung ','lucu ','merupakan ','pertama ','kalinya ','publik ','melihat ','foto ','chicago ','kini ','berusia ','enam ','minggu ','dilahirkan ','ibu ','pengganti ','bayi ','chicago ','sesederhana ','kim ','menuliskan ','keterangan ','fotonya ','foto ','sang ','istri ','kanye ','west ','menggendong ','chicago ','mengenakan ','busana ','senada ','dirinya ','berwarna ','pastel ','chicago ',
# Summary: kim kardashian akhirnya memamerkan foto anak ketiganya chicago west senin kemarin kim mengunggah fotonya bersama chicago ke instagram meski diberi pula efek telinga
# Generated: kim kardashian akhirnya memamerkan foto anak ketiganya di chicago pada senin kemarin kim mengunggah foto bersama ibunya yang imut di instagram meski
# ====================================================================================================
# Review: ['suara ','com ','calon ','gubernur ','jawa ','tengah ','nomor ','urut ','sudirman ','said ','pulang ','kampung ','menuju ','tanah ','kelahirannya ','brebes ','lantaran ','diterjang ','banjir ','minggu ','sudirman ','mengunjungi ','tempat ','penampungan ','pengungsi ','desa ','kecipir ','losari ','melihat ','persediaan ','stok ','pangan ','pengungsi ','meski ','menu ','seadanya ','ikan ','asin ','sambal ','tempe ','semangat ','warga ','tinggi ','bertahan ','kata ','sudirman ','pasangan ','cawagub ','jateng ','ida ','fauziyah ','menyusuri ','lokasi ','banjir ','desa ','kecipir ','berdialog ','warga ','membantu ','relawan ','memberikan ', '
# Summary: calon gubernur jawa tengah nomor urut sudirman said pulang kampung menuju tanah kelahirannya brebes lantaran kembali diterjang banjir minggu pasangan cawagub jateng ida fauziyah ini
# Generated: calon gubernur jawa tengah nomor urut sudirman said akan pulang kampung ke kampung halamannya di brebes lantaran diterjang banjir di daerahnya sudirman menyambangi lokasi penampungan pengungsi korban banjir
# ====================================================================================================
# Review: ['suara ','com ','bila ','tak ','segera ','diselesaikan ','konflik ','kepengurusan ','tubuh ','partai ','hanura ','bakal ','berdampak ','besar ','keikutsertaannya ','pemilu ','hanura ','terancam ','lolos ','verifikasi ','partai ','politik ','lantaran ','terjadi ','perpecahan ','kepengurusan ','kalau ','parpol ','menyesuaikan ','menentukan ','siapa ','ketumnya ','siapa ','sekjennya ','punya ','resiko ','akan ','bisa ','lolos ','verifikasi ','faktual ','kata ','mantan ','komisioner ','kpu ','hadar ','navis ','gumay ','warung ','daun ','cikini ','jakarta ','pusat ','sabtu ','mengatakan ','partai ','hanura ','mengikuti ','aturan ','ditetapkan ','termasuk ','soal
# Summary: bila tak segera diselesaikan konflik kepengurusan di tubuh partai hanura bakal berdampak besar pada keikutsertaannya di pemilu sebab hanura bisa terancam tidak lolos verifikasi partai politik lantaran
# Generated: bila tak segera diselesaikan persoalan kepengurusan partai hanura bakal segera berdampak pada keikutsertaannya di politik di pemilu hanura terancam terancam gagal lolos ke pemilu lantaran bisa lolos
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','kepala ','staf ','tni ','angkatan ','udara ','ksau ','marsekal ','tni ','yuyu ','sutisna ','mengatakan ','rencana ','pembelian ','pesawat ','tempur ','generasi ','sukhoi ','pemerintah ','rusia ','terus ','berjalan ','sukhoi ','jalan ','ada ','pengaruh ','apa ','apa ','sesuai ','apa ','disampaikan ','panglima ','tni ','marsekal ','tni ','hadi ','tjahjanto ','kata ','yuyu ','usai ','rapat ','pimpinan ','rapim ','tni ','angkatan ','udara ','cilangkap ','jakarta ','timur ','jumat ','dikutip ','ksau ','mengatakan ','menanggapi ','informasi ','tekanan ','pemerintah ','amerika ','serikat ', '
# Summary: ksau marsekal tni yuyu sutisna mengatakan rencana pembelian pesawat tempur generasi sukhoi dari pemerintah rusia masih terus berjalan ksau mengatakan hal itu menanggapi
# Generated: kepala staf angkatan udara ksau marsekal tni yuyu sutisna mengatakan rencana pembelian pesawat tempur generasi ke rusia dari rusia akan terus berjalan meski begitu
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','pt ','golden ','energy ','mines ','tbk ','gems ','mengantongi ','pinjaman ','sebesar ','us ','juta ','pt ','bank ','mandiri ','tbk ','bmri ','mayoritas ','raihan ','dana ','diberikan ','anak ','usaha ','pt ','borneo ','indobara ','bib ','sekretaris ','perusahaan ','golden ','energy ','sudin ','sh ','mengatakan ','manajemen ','menyuntikan ','dana ','segar ','borneo ','indobara ','sebesar ','us ','juta ','kebutuhan ','belanja ','modal ','capital ','expenditure ','capex ','salah ','satu ','proyek ','perusahaan ','tujuan ','penggunaan ','pembiayaan ','capex ','pembangunan ', '
# Summary: pt golden energy mines tbk gems mengantongi pinjaman sebesar us juta dari pt bank mandiri tbk bmri mayoritas raihan dana itu akan diberikan kepada anak
# Generated: pt golden energy tbk tbk telah mengantongi pinjaman sebesar us juta dari pt bank mandiri bmri bmr bmk mayoritas raihan anak usahanya itu merupakan raihan
# ====================================================================================================
# Review: ['sebagian ','besar ','masyarakat ','indonesia ','tahu ','serial ','keluarga ','cemara ','populer ','era ','an ','menjadi ','salah ','satu ','serial ','terbaik ','selalu ','dinantikan ','penggemarnya ','serial ','keluarga ','ditulis ','arswendo ','atmowiloto ','banyak ','dijadikan ','panutan ','keluarga ','indonesia ','hidup ','berkeluarga ','baik ','atas ','dasar ','rumah ','produksi ','visinema ','pictures ','mengangkat ','konsep ','dasar ','cerita ','tersebut ','medium ','lebih ','besar ','layar ','lebar ','anggia ','kharisma ','salah ','satu ','produser ','film ','menjelaskan ','alasannya ','tertarik ','mengangkat ','kisah ','keluarga ','cemara
# Summary: serial keluarga cemara yang populer di era an kini akan diangkat ke layar lebar karakter abah dan emak yang ikonik nantinya doperankan ringgo agus rahman
# Generated: serial keluarga cemara yang sudah tayang sejak tahun lalu mengangkat cerita tentang keluarga yang memiliki cerita keluarga layak diangkat dengan cerita yang mengalir dalam bingkai cerita dramatik

# %%
df_reviews_test = pd.read_csv("/content/Test13.csv")
test_reviews = df_reviews_test['paragraphs'].values
test_sums = df_reviews_test['summary'].values

test_dataloader = DataLoader(test_reviews, test_sums, **dataloader_args)
test_dataset = test_dataloader.list_to_tensor_dataset(test_reviews, test_sums)
test_dataset = test_dataset.batch(training_config.batch_size)
pred_strs = []
gold_strs = []

for batched_input in tqdm(test_dataset):
    pred_str, gold_str, _ = batched_generate_summary(
        trained_bert2bert, 
        tokenizer, 
        batched_input
    )
    pred_strs.extend(pred_str)
    gold_strs.extend(gold_str)
    
rouge_output = rouge.compute(
    predictions=pred_strs,
    references=gold_strs,
    rouge_types=["rouge1","rouge2","rougeL"]
)
# Out:
#   0%|          | 0/236 [00:00<?, ?it/s]

# %%
print('Rouge report: ')
print("ROUGE 1 SCORE: ",rouge_output['rouge1'].mid)
print("ROUGE 2 SCORE: ",rouge_output['rouge2'].mid)
print("ROUGE F SCORE: ",rouge_output['rougeL'].mid)
# Out:
# Rouge report:
# ROUGE 1 SCORE:  Score(precision=0.25525797576409337, recall=0.24685767139633086, fmeasure=0.25032806124905016)
# ROUGE 2 SCORE:  Score(precision=0.07826334084671874, recall=0.07577941804726684, fmeasure=0.0767759072347329)
# ROUGE F SCORE:  Score(precision=0.21240653467507106, recall=0.2053867597132295, fmeasure=0.20832780282905755)

# %%
rouge_output
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.2517084824566403, recall=0.243408299303038, fmeasure=0.24690319528118748), mid=Score(precision=0.25525797576409337, recall=0.24685767139633086, fmeasure=0.25032806124905016), high=Score(precision=0.25854363396461394, recall=0.25007055657269645, fmeasure=0.25363203427228037)),
#  'rouge2': AggregateScore(low=Score(precision=0.07549633620291295, recall=0.07317216886046964, fmeasure=0.07413624175754727), mid=Score(precision=0.07826334084671874, recall=0.07577941804726684, fmeasure=0.0767759072347329), high=Score(precision=0.08096104176670475, recall=0.07831515377127632, fmeasure=0.07941857035800888)),
#  'rougeL': AggregateScore(low=Score(precision=0.20916083155556628, recall=0.2022908659117261, fmeasure=0.20518189865954292), mid=Score(precision=0.21240653467507106, recall=0.2053867597132295, fmeasure=0.20832780282905755), high=Score(precision=0.21582594204525438, recall=0.20876189689388389, fmeasure=0.2117095091268812))}

# %%
# !cp -r /content/bert2bert-Checkpoint-epoch7-loss2.5399999618530273 "/content/drive/MyDrive"

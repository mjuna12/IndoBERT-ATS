# %%
# %%capture
# !pip install rouge_score
# !pip install datasets
# !pip install transformers
! pip install dill==0.3.6
import datasets
import transformers

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd 
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import transformers
from transformers import BertTokenizerFast, TFEncoderDecoderModel, AdamWeightDecay
from sklearn.model_selection import train_test_split

from tqdm.notebook import tqdm
from tensorflow.python.ops.numpy_ops import np_config
from pprint import pprint
""
# enable model saving at eager mode
np_config.enable_numpy_behavior()
print('transformers version:', transformers.__version__)
print('tensorflow version:', tf.__version__)
# Out:
# transformers version: 4.25.1
# tensorflow version: 2.9.2

# %%
df_reviews=pd.read_csv("/content/Experiment6.csv")
df_reviews.head()
# Out:
#    Unnamed: 0                                         paragraphs  \
# 0           0  jakarta cnn indonesia - - dokter ryan thamrin ...
# 1           1  selfie ialah salah satu tema panas di kalang p...
# 2           2  jakarta cnn indonesia - - dinas pariwisata pro...
# 3           3  merdeka com - indonesia corruption watch icw m...
# 4           4  merdeka com - presiden joko widodo jokowi pimp...
#
#                                              summary
# 0  [['Dokter', 'Lula', 'Kamal', 'yang', 'merupaka...
# 1  [['Asus', 'memperkenalkan', '\xa0', 'ZenFone',...
# 2  [['Dinas', 'Pariwisata', 'Provinsi', 'Bengkulu...
# 3  [['Indonesia', 'Corruption', 'Watch', '(', 'IC...
# 4  [['Jokowi', 'memimpin', 'upacara', 'penurunan'...

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14262 entries, 0 to 14261
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  14262 non-null  int64
#  1   paragraphs  14262 non-null  object
#  2   summary     14262 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 334.4+ KB

# %%
import nltk #import library nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize #import word_tokenize for tokenizing text into words 
#word tokenization
def word_tokenization(s):
    tokens = word_tokenize(s)
    return tokens

df_reviews['paragraphs'] = df_reviews['paragraphs'].apply(word_tokenization).apply(str)
pd.DataFrame(df_reviews['paragraphs'])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#                                               paragraphs
# 0      ['jakarta', 'cnn', 'indonesia', '-', '-', 'dok...
# 1      ['selfie', 'ialah', 'salah', 'satu', 'tema', '...
# 2      ['jakarta', 'cnn', 'indonesia', '-', '-', 'din...
# 3      ['merdeka', 'com', '-', 'indonesia', 'corrupti...
# 4      ['merdeka', 'com', '-', 'presiden', 'joko', 'w...
# ...                                                  ...
# 14257  ['jakarta', 'cnn', 'indonesia', '-', '-', 'ame...
# 14258  ['bandung', 'cnn', 'indonesia', '-', '-', 'bor...
# 14259  ['jakarta', 'pos', 'kota', 'komisi', 'berantas...
# 14260  ['merdeka', 'com', '-', 'buah', 'kabar', 'gemb...
# 14261  ['ada', 'satu', 'perangkat', 'tarik', 'lain', ...
#
# [14262 rows x 1 columns]

# %%
df_reviews.to_pickle('df.pkl')

# %%
df_reviews = pd.read_pickle('df.pkl')
df_reviews_sampled = df_reviews.copy()
# sampling n pairs of reviews and summarizies on shuffled dataframe
df_reviews_sampled = df_reviews_sampled.iloc[:40000, :]
df_reviews_sampled['text_len'] = df_reviews_sampled['paragraphs'].apply(lambda x: len(x.split()))
df_reviews_sampled['summary_len'] = df_reviews_sampled['summary'].apply(lambda x: len(x.split()))
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16,5))
ax[0].hist(df_reviews_sampled['text_len'])
ax[0].set_xticks(np.arange(0, max(df_reviews_sampled['text_len'])+1,250))
ax[0].set_title('Histogram of length of tokenized text')
ax[1].hist(df_reviews_sampled['summary_len'], color='yellow')
ax[1].set_xticks(np.arange(0, max(df_reviews_sampled['summary_len'])+1,5))
ax[1].set_title('Histogram of length of tokenized summary')
# Out:
# Text(0.5, 1.0, 'Histogram of length of tokenized summary')

# %%
class TrainingConfig:
    from_pt=True 
    val_split = 0.2
    pretrained_checkpoint = 'indolem/indobert-base-uncased'
    encoder_checkpoint = 'indolem/indobert-base-uncased'
    decoder_checkpoint = 'indolem/indobert-base-uncased'
    pad_token_id = 0
    shared_weight = False
    encoder_max_len = 256 
    decoder_max_len = 30 
    nb_epoch = 7 
    learning_rate = 3e-5 
    batch_size = 16
    
    
    def __init__(self, **kwargs):
        for k,v in kwargs.items():
            setattr(self, k, v)

# %%
class DataLoader:
    def __init__(self, paragraphs, summaries, **kwargs):
        self.paragraphs = paragraphs 
        self.summaries = summaries 
        self.tokenizer = kwargs.get('tokenizer')
        self.val_split = kwargs.get('val_split')
        self.encoder_max_len = kwargs.get('encoder_max_len')
        self.decoder_max_len = kwargs.get('decoder_max_len')
    
    @property
    def sample_size(self):
        assert len(self.paragraphs)==len(self.summaries)
        return len(self.paragraphs)
    
    def split_train_test(self):
        train_idx, val_idx = train_test_split(
            list(range(self.sample_size)), 
            test_size=self.val_split, 
            random_state=98
        )
        return train_idx, val_idx
    
    def convert_text_to_ids(self, input_paragraphs, input_summaries):
        inputs = self.tokenizer(
            list(input_paragraphs), 
            return_tensors='np', 
            padding='max_length', 
            truncation=True, 
            max_length=self.encoder_max_len
        )
        outputs = self.tokenizer(
            list(input_summaries), 
            return_tensors='np', 
            padding='max_length', 
            truncation=True, 
            max_length=self.decoder_max_len
        )
        return inputs, outputs
    
    def list_to_tensor_dataset(self, input_paragraphs, input_summaries):
        inputs, outputs = self.convert_text_to_ids(
            input_paragraphs, 
            input_summaries
        )
        input_ids = tf.data.Dataset.from_tensor_slices(
            inputs['input_ids']
        )
        attention_masks = tf.data.Dataset.from_tensor_slices(
            inputs['attention_mask']
        )
        output_ids = tf.data.Dataset.from_tensor_slices(
            outputs['input_ids']
        )
        output_attention_masks = tf.data.Dataset.from_tensor_slices(
            outputs['attention_mask']
        )                                                
        tf_dataset = tf.data.Dataset.zip(
            ({
                'input_ids': input_ids, 
                'attention_mask': attention_masks,
                'decoder_input_ids': output_ids, 
                 'decoder_attention_mask': output_attention_masks
            }, 
            output_ids)
        )
        return tf_dataset
    
    def __call__(self):
        train_idx, val_idx = self.split_train_test()
        train_paras, val_paras = self.paragraphs[train_idx], self.paragraphs[val_idx]
        train_sums, val_sums = self.summaries[train_idx], self.summaries[val_idx]
        train_dataset = self.list_to_tensor_dataset(train_paras, train_sums)
        val_dataset = self.list_to_tensor_dataset(val_paras, val_sums)
        return train_dataset, val_dataset

# %%
class Seq2SeqLoss(tf.keras.losses.Loss):
    def __init__(self, pad_token_id, name="seq2seq_loss"):
        super().__init__(name=name)
        self.pad_token_id = pad_token_id

    def call(self, y_true, y_pred):
        loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(
            from_logits=True, 
            reduction=tf.keras.losses.Reduction.NONE
        )
        # shift the label and output sequences to match  
        output_logits = y_pred[:,:-1,:]
        input_labels = y_true[:,1:] 
        loss = loss_fn(input_labels, output_logits)
        # calculate loss without the padding tokens in label sequence
        mask = tf.cast((input_labels != self.pad_token_id), dtype=tf.float32)
        loss = loss * mask
        return tf.reduce_sum(loss) / tf.reduce_sum(mask)

# %%
class Trainer:
    def __init__(self, model, loss_fn, optimizer, metric):
        self.model = model
        self.loss_fn = loss_fn
        self.optimizer = optimizer
        self.metric = metric
        # loss tracker will capture the mean of loss till now
        self.loss_tracker = tf.keras.metrics.Mean(name='mean_loss')
    
    # Training Step
    @tf.function 
    def train_step(self, inputs):
        input_seqs, input_labels = inputs
        with tf.GradientTape() as tape: 
            outputs = self.model(
                input_seqs['input_ids'],
                input_seqs['attention_mask'],
                input_seqs['decoder_input_ids'],
                input_seqs['decoder_attention_mask'],
                training = True
            )
            logits = outputs.logits
            loss = self.loss_fn(input_labels, logits)
        gradients = tape.gradient(loss, self.model.trainable_weights)
        self.optimizer.apply_gradients(
            zip(gradients, self.model.trainable_weights)
        )
        self.loss_tracker.update_state(loss)
#         self.metric.update_state(y, predictions)
        return loss
        
    # Validation Step
    @tf.function  
    def val_step(self, inputs):
        input_seqs, input_labels = inputs
        outputs = self.model(                
                input_seqs['input_ids'],
                input_seqs['attention_mask'],
                input_seqs['decoder_input_ids'],
                input_seqs['decoder_attention_mask'],
                training = False
        )
        logits = outputs.logits
        loss = self.loss_fn(input_labels, logits)
        self.loss_tracker.update_state(loss)
#         self.metric.update_state(y,predictions)
        return loss

# %%
def batched_generate_summary(model, tokenizer, batched_input):
    input_seqs, input_labels = batched_input
    outputs = model.generate(
        input_ids=input_seqs['input_ids'], 
        attention_mask=input_seqs['attention_mask']
    )
    output_strs = tokenizer.batch_decode(
        outputs, 
        skip_special_tokens=True
    )
    output_gold = tokenizer.batch_decode(
        input_seqs['decoder_input_ids'], 
        skip_special_tokens=True
    )
    input_strs = tokenizer.batch_decode(
        input_seqs['input_ids'], 
        skip_special_tokens=True
    )
    return output_strs, output_gold, input_strs

# %%
reviews = df_reviews_sampled['paragraphs'].values
summaries = df_reviews_sampled['summary'].values

training_config = TrainingConfig(nb_epoch=7)
tokenizer = BertTokenizerFast.from_pretrained(training_config.encoder_checkpoint)

dataloader_args = {
    'tokenizer': tokenizer,
    'val_split': training_config.val_split,
    'encoder_max_len': training_config.encoder_max_len,
    'decoder_max_len': training_config.decoder_max_len
}
dataloader = DataLoader(reviews, summaries, **dataloader_args)
train_dataset, val_dataset = dataloader()
train_dataset = (train_dataset
                 .shuffle(int(dataloader.sample_size*(1-training_config.val_split)))
                 .batch(training_config.batch_size))
val_dataset = val_dataset.batch(training_config.batch_size)
# Out:
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/234k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.01k [00:00<?, ?B/s]

# %%
model = transformers.EncoderDecoderModel.from_encoder_decoder_pretrained(
    training_config.encoder_checkpoint, 
    training_config.decoder_checkpoint,
    tie_encoder_decoder=training_config.shared_weight,from_pt=True)
# Out:
# Downloading:   0%|          | 0.00/445M [00:00<?, ?B/s]

# %%
model.save_pretrained('indolem/indobert-base-uncased')
model = TFEncoderDecoderModel.from_pretrained('/content/indolem/indobert-base-uncased',from_pt=True)

# %%
model.config.decoder_start_token_id = tokenizer.cls_token_id # 101
model.config.eos_token_id = tokenizer.sep_token_id # 102 
model.config.pad_token_id = tokenizer.pad_token_id # 0
model.config.vocab_size = model.config.encoder.vocab_size

# %%
model.config.max_length = 30
model.config.min_length = 3
model.config.no_repeat_ngram_size = 2
model.config.early_stopping = True
model.config.length_penalty = 2.0
model.config.num_beams = 4

# %%
#rouge = datasets.load_metric('rouge')
tf.keras.backend.clear_session()
trainer = Trainer(model=model,
                  loss_fn=Seq2SeqLoss(training_config.pad_token_id),
                  optimizer=AdamWeightDecay(
                      learning_rate=training_config.learning_rate, 
                      weight_decay_rate=0.005),
                  metric=None)

# %%
import datasets
rouge = datasets.load_metric("rouge")
for epoch in range(training_config.nb_epoch):
    print(f'\nEpoch {epoch+1}\n')
    print('Training....')
    for step,batched_input in enumerate(tqdm(train_dataset)):
        loss = trainer.train_step(batched_input)
        till_now_loss = trainer.loss_tracker.result()
        if step%200 == 0:
            print(f'Training loss for one batch at step {step}: {round(till_now_loss,3)}') 
    trainer.loss_tracker.reset_states()
    print('Validating....')
    val_measures = {'rouge precision':0, 'rouge recall':0, 'rouge f1': 0}
    for step, batched_input in enumerate(tqdm(val_dataset)):
        val_loss = trainer.val_step(batched_input)
    till_now_val_loss = trainer.loss_tracker.result()
    print(f'Validation loss: {round(till_now_val_loss,3)}')
    model.save_pretrained(
        f'bert2bert-Checkpoint-epoch{epoch+1}-loss{round(till_now_val_loss,3)}'
    )
    trainer.loss_tracker.reset_states()
# Out:
# <ipython-input-20-adafa7a0519c>:2: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   rouge = datasets.load_metric("rouge")
# Downloading builder script:   0%|          | 0.00/2.16k [00:00<?, ?B/s]
# Epoch 1
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# WARNING:tensorflow:Gradients do not exist for variables ['tf_encoder_decoder_model/encoder/bert/pooler/dense/kernel:0', 'tf_encoder_decoder_model/encoder/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_encoder_decoder_model/encoder/bert/pooler/dense/kernel:0', 'tf_encoder_decoder_model/encoder/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# Training loss for one batch at step 0: 7.7220001220703125
# Training loss for one batch at step 200: 2.7170000076293945
# Training loss for one batch at step 400: 2.378999948501587
# Training loss for one batch at step 600: 2.197000026702881
# WARNING:tensorflow:Gradients do not exist for variables ['tf_encoder_decoder_model/encoder/bert/pooler/dense/kernel:0', 'tf_encoder_decoder_model/encoder/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 1.5490000247955322
#
# Epoch 2
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 1.7000000476837158
# Training loss for one batch at step 200: 1.4850000143051147
# Training loss for one batch at step 400: 1.3930000066757202
# Training loss for one batch at step 600: 1.3229999542236328
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 1.0399999618530273
#
# Epoch 3
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 0.8519999980926514
# Training loss for one batch at step 200: 0.9200000166893005
# Training loss for one batch at step 400: 0.906000018119812
# Training loss for one batch at step 600: 0.8899999856948853
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 0.8709999918937683
#
# Epoch 4
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 0.6320000290870667
# Training loss for one batch at step 200: 0.6589999794960022
# Training loss for one batch at step 400: 0.6610000133514404
# Training loss for one batch at step 600: 0.652999997138977
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 0.7979999780654907
#
# Epoch 5
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 0.3499999940395355
# Training loss for one batch at step 200: 0.47200000286102295
# Training loss for one batch at step 400: 0.47200000286102295
# Training loss for one batch at step 600: 0.4729999899864197
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 0.7689999938011169
#
# Epoch 6
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 0.38100001215934753
# Training loss for one batch at step 200: 0.3440000116825104
# Training loss for one batch at step 400: 0.34299999475479126
# Training loss for one batch at step 600: 0.34700000286102295
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 0.7540000081062317
#
# Epoch 7
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 0.30399999022483826
# Training loss for one batch at step 200: 0.24500000476837158
# Training loss for one batch at step 400: 0.24500000476837158
# Training loss for one batch at step 600: 0.25099998712539673
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 0.7590000033378601

# %%
# from transformers import 
import datasets
rouge = datasets.load_metric("rouge")
trained_bert2bert = TFEncoderDecoderModel.from_pretrained("/content/bert2bert-Checkpoint-epoch7-loss0.7590000033378601")

# val0 = list(val_dataset.as_numpy_iterator())[0]
for step, batched_input in enumerate(tqdm(val_dataset)):
    pred_str, gold_str, input_strs = batched_generate_summary(
        trained_bert2bert, 
        tokenizer, 
        batched_input
    )
    rouge_output = rouge.compute(
        predictions=pred_str,
        references=gold_str,
        rouge_types=["rouge1","rouge2","rougeL"]
    )
    print('Rouge report: ')
    print("ROUGE 1 SCORE: ",rouge_output['rouge1'].mid)
    print("ROUGE 2 SCORE: ",rouge_output['rouge2'].mid)
    print("ROUGE F SCORE: ",rouge_output['rougeL'].mid)
    for p_str,g_str,in_str in zip(pred_str, gold_str, input_strs):
        print('='*100)
        print('Review: ' + in_str)
        print('Summary: ' + g_str)
        print('Generated: ' + p_str)
    
    break
# Out:
#   0%|          | 0/179 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/transformers/generation/tf_utils.py:1800: UserWarning: Neither `max_length` nor `max_new_tokens` have been set, `max_length` will default to 30 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Rouge report:
# ROUGE 1 SCORE:  Score(precision=0.24166666666666667, recall=0.2136904761904762, fmeasure=0.223018648018648)
# ROUGE 2 SCORE:  Score(precision=0.06666666666666667, recall=0.06875, fmeasure=0.06691919191919192)
# ROUGE F SCORE:  Score(precision=0.22566964285714286, recall=0.20461309523809523, fmeasure=0.21165501165501163)
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','- ','- ','direktur ','utama ','pt ','transjakarta ','budi ','kaliwono ','minta ','maaf ','kepada ','langgan ','kait ','ganggu ','layan ','transjakarta ','di ','beberapa ','koridor ','yang ','sebab ','aksi ','karyawan ','tuntut ','naik ','gaji ','dan ','tetap ','status ','karyawan ','tetap ','senin ','12 ','6 ','kami ','rasa ','salah ','pada ','langgan ','karena ','ada ','ganggu ','ini ','kata ','budi ','saat ','temu ','di ','kantor ','yang ','ada ','di ','kawasan ','cawang ','jakarta ','timur ','budi ','kata ','tidak '
# Summary: [ ['\ xa0 ','direktur ','utama ','pt ','transjakarta ', ', ',
# Generated: [ ['dirut ','pt '.'], [ "'budi';'kaliwono - - baru'layanan '
# ====================================================================================================
# Review: ['jakarta ','putra ','dua ','venna ','melinda ','athalla ','naufal ','alami ','celaka ','pada ','jumat ','29 ','9 ','2017 ','malam ','di ','kawasan ','jagakarsa ','jakarta ','selatan ','mobil ','yang ','kendara ','adik ','verrell ','bramasta ','itu ','hancur ','karena ','beberapa ','kali ','tabrak ','tiang ','meski ','kendara ','dalam ','kondiri ','ringsek ','untung ','athalla ','tak ','alami ','cedera ','serius ','sempat ','lari ','ke ','rumah ','sakit ','pondok ','indah ','namun ','athalla ','ungkap ','diri ','baik ','saja ','jadi ','ini ',
# Summary: [ ['putra ','kedua ','venna ','melinda ', ', ','athalla
# Generated: [ ['putra ','kedua '. ], [na'suhelia';'silvanala'—'israel
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','- ','- ','tim ','kuasa ','hukum ','gnpf ','kapitra ','ampera ','sebut ','pentol ','front ','bela ','islam ','rizieq ','shihab ','saat ','ini ','ada ','di ','malaysia ','dia ','xa0 ','kata ','ada ','rizieq ','di ','malaysia ','beberapa ','hari ','usai ','laksana ','ibadah ','umrah ','di ','arab ','saudi ','kapitra ','kata ','rizieq ','di ','malaysia ','untuk ','konsultasi ','xa0 ','disertasi ','studi ','di ','malaysia ','dia ','sampai ','rizieq ','akan ','kembali ','ke ','indonesia ','pekan ','depan ','meski ', '
# Summary: [ ['tim ','kuasa ','hukum ','gnpf ','kapitra ','ampera
# Generated: [ ['tim ','kuasa '. org.pp.'], [pff. com'menyatakan''
# ====================================================================================================
# Review: ['lewat ','main ','baru ','hitman ','io ','interactive ','tebus ','jumlah ','keliru ','pada ','arah ','desain ','hitman ','absolution ','di ','sana ','developer ','kembali ','gameplay ','sandbox ','ala ','blood ','money ','sila ','main ','eksplorasi ','dan ','tentu ','sendiri ','cara ','baik ','untuk ','selesai ','misi ','serta ','tak ','lupa ','suguh ','xa0 ','map ','xa0 ','tujuh ','kali ','lebih ','besar ','dari ','absolution ','namun ','hitman ','2016 ','suguh ','lalu ','metode ','yang ','unik ','untuk ','pertama ','kali ','di ','franchise ',
# Summary: [ ['lewat ','permainan ','baru ','hitman ', ', ','io ', '
# Generated: [ ['kali ','ini '. com. main maintenant'], "'", \ xa0''
# ====================================================================================================
# Review: ['merdeka ','com ','- ','orang ','ahli ','cokelat ','asal ','swiss ','telah ','cipta ','batang ','cokelat ','yang ','klaim ','mampu ','atas ','nyeri ','haid ','tanya ','apakah ','makan ','sederhana ','cokelat ','benar ','bisa ','ringan ','rasa ','sakit ','menstruasi ','yang ','kadang ','bisa ','begitu ','tak ','tahan ','lansir ','dailymail ','marc ','widmer ','klaim ','kalau ','cokelat ','batang ','frauenmond ','yang ','dia ','kreasi ','bisa ','buat ','wanita ','yang ','sedang ','haid ','hindar ','dari ','nyeri ','dan ','kram ','perut ','cokelat ','ini ',
# Summary: [ ['dilansir ','dailymail ', ', ','marc ','widmer ','seorang '
# Generated: [ ['seorang ','ahli '. co'], "'", cokelat'asal'[ " ". com '
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','- ','- ','ketua ','komisi ','ix ','dpr ','ri ','dede ','yusuf ','macan ','effendi ','aku ','telah ','minta ','partai ','demokrat ','siap ','diri ','untuk ','masuk ','dalam ','bursa ','nama ','calon ','gubernur ','dalam ','pilgub ','jawa ','barat ','2018 ','pilgub ','masih ','dinamis ','saya ','masih ','minta ','oleh ','partai ','untuk ','siap ','diri ','saya ','dan ','keluarga ','masih ','lihat ','dulu ','apakah ','saat ','ini ','memang ','sangat ','butuh ','oleh ','rakyat ','jawa ','barat ','atau ','tidak ','ujar '
# Summary: [ ['ketua ','komisi ','ix ','dpr ','ri ','dede ','yusuf
# Generated: [ ['\ xa0 ','ketua '.'], "'bkp ", -'". oesman '
# ====================================================================================================
# Review: ['singapura ','cnn ','indonesia ','- ','- ','cerita ','rakyat ','dan ','agam ','mitos ','xa0 ','bagi ','masyarakat ','asia ','bukan ','hal ','yang ','baru ','akrab ','ini ','yang ','tangkap ','oleh ','jumlah ','sutradara ','di ','asia ','masuk ','joko ','anwar ','dari ','indonesia ','untuk ','jadi ','buah ','serial ','televisi ','tajuk ','folklore ','selain ','joko ','anwar ','serial ','yang ','payung ','hbo ','asia ','ini ','gandeng ','sutradara ','asal ','singapura ','eric ','khoo ','yang ','sekaligus ','cipta ','seri ','sebut ','lalu ','ada ','ho ',
# Summary: [ ['cerita ','rakyat ','dan ','mitos ','bagi ','masyarakat ','asia
# Generated: [ ['cerita ','rebornang - - nya '.'dan'& '?'], "'"
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','- ','- ','gabung ','produsen ','rokok ','putih ','indonesia ','gaprindo ','aku ','kecewa ','dengan ','putus ','perintah ','yang ','kerek ','tarif ','pajak ','tambah ','nilai ','ppn ','hasil ','tembakau ','dari ','8 ','7 ','persen ','jadi ','9 ','1 ','persen ','ketua ','umum ','gaprindo ','muhaimin ','moeftie ','kata ','benar ','rencana ','naik ','sudah ','tahu ','asosiasi ','sejak ','agustus ','2016 ','lalu ','kala ','diskus ','dengan ','badan ','bijak ','fiskal ','bkf ','menteri ','uang ','hanya ','saja ','diskusi ',
# Summary: [ ['gabungan ','pengusaha ','rokok ','putih ','\ xa0 ','indonesia ',
# Generated: [ ['\ xa0 ','gabungan '. co'], [.'ojko. id'/ / '
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','- ','- ','menteri ','hukum ','dan ','ham ','yasonna ','hamonangan ','laoly ','kata ','pihak ','tunggu ','undang ','badan ','legislasi ','dpr ','untuk ','bicara ','revisi ','undang ','mpr ','dpr ','dpd ','dprd ','md3 ','dia ','harap ','baleg ','dpr ','segera ','undang ','kemenkumham ','agar ','revisi ','uu ','md3 ','dapat ','cepat ','selesai ','saya ','tunggu ','undang ','dari ','baleg ','kalau ','perlu ','segera ','ujar ','yasonna ','di ','kantor ','kemenkumham ','jakarta ','sabtu ','malam ','13 ','1 ',
# Summary: [ ['menkumham ','yasonna ','laoly ','mengatakan ','pihaknya ','menunggu
# Generated: [ ['\ xa0 ','menkumhukam '. hamham.'yasonnaonna'dan'hukumda '
# ====================================================================================================
# Review: ['ada ','banyak ','kamera ','awas ','yang ','bisa ','kita ','guna ','di ','rumah ','atau ','kantor ','untuk ','tingkat ','aman ','harga ','agam ','gantung ','dari ','canggih ','serta ','lengkap ','fiturnya ','namun ','lemah ','besar ','kamera ','cctv ','standar ','letak ','pada ','titik ','buta ','karena ','perangkat ','ini ','paut ','di ','satu ','posisi ','solusi ','anda ','harus ','pakai ','lebih ','dari ','satu ','unit ','buah ','solusi ','inovatif ','tawar ','oleh ','tim ','aevena ','dengan ','ide ','yang ','adopsi ','dari ','perangkat ','spesialis ', '
# Summary: [ ['sebuah ','solusi ','inovatif ','ditawarkan ','oleh ','tim ','ae
# Generated: [ ['dengan ','sistem '. com'], "'yang ",a'memadukan';'performa'[
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','- ','- ','kim ','kardashian ','xa0 ','akhir ','pamer ','foto ','anak ','tiga ','chicago ','west ','senin ','26 ','2 ','kemarin ','kim ','unggah ','foto ','sama ','chicago ','ke ','instagram ','meski ','beri ','pula ','efek ','telinga ','dan ','hidung ','lucu ','itu ','rupa ','pertama ','kali ','publik ','bisa ','lihat ','foto ','chicago ','yang ','kini ','usia ','enam ','minggu ','telah ','lahir ','dari ','ibu ','ganti ','bayi ','chicago ','sederhana ','itu ','kim ','tulis ','terang ','foto ','dalam '
# Summary: [ ['kim ','kardashian ','akhirnya ','memamerkan ','foto ','anak ',
# Generated: [ ['kim ','kardashian '. com'], \ xa0 [ " ", "'posesif '
# ====================================================================================================
# Review: ['suara ','com ','- ','calon ','gubernur ','jawa ','tengah ','nomor ','urut ','2 ','sudirman ','said ','pulang ','kampung ','tuju ','tanah ','lahir ','brebes ','lantar ','kembali ','terjang ','banjir ','minggu ','25 ','2 ','2018 ','sudirman ','unjung ','tempat ','tampung ','ungsi ','di ','desa ','kecipir ','dan ','losari ','untuk ','lihat ','sedia ','stok ','pangan ','para ','ungsi ','meski ','menu ','ada ','seperti ','ikan ','asin ','dan ','sambal ','dan ','tempe ','semangat ','warga ','masih ','tinggi ','untuk ','tahan ','kata ','sudirman ','pasang
# Summary: [ ['calon ','gubernur ','jawa ','tengah ','nomor ','urut ','2
# Generated: [ ['pilgub ','nomor. 002. ahok ’ ’ \ r \ t \ n \ \ xa0 '
# ====================================================================================================
# Review: ['suara ','com ','- ','bila ','tak ','segera ','selesai ','konflik ','urus ','di ','tubuh ','partai ','hanura ','bakal ','dampak ','besar ','pada ','keikutsertaannya ','di ','milu ','2019 ','sebab ','hanura ','bisa ','ancam ','tidak ','lolos ','verifikasi ','partai ','politik ','lantar ','saat ','ini ','jadi ','pecah ','urus ','kalau ','parpol ','itu ','tidak ','bisa ','sesuai ','tidak ','bisa ','tentu ','siapa ','tum ','siapa ','sekjennya ','ya ','mereka ','akan ','punya ','resiko ','tidak ','akan ','bisa ','lolos ','di ','dalam ','verifikasi ','faktual ',
# Summary: [ ['bila ','tak ','segera ','diselesaikan ', ', ','konflik ','kepengurusan
# Generated: [ ['tak ','mudah '.'], [ "'", " " \ xa0 '?'konflik '
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','- ','- ','kepala ','staf ','tni ','angkat ','udara ','ksau ','marsekal ','tni ','yuyu ','sutisna ','kata ','rencana ','beli ','pesawat ','tempur ','generasi ','4 ','5 ','sukhoi ','- ','35 ','dari ','perintah ','rusia ','masih ','terus ','jalan ','sukhoi ','- ','35 ','masih ','jalan ','tidak ','ada ','pengaruh ','apa ','sesuai ','dengan ','apa ','yang ','sampai ','panglima ','tni ','marsekal ','tni ','had ','tjahjanto ','kata ','yuyu ','usai ','rapat ','pimpin ','rapim ','tni ','angkat ','udara ','2018 '
# Summary: [ ['ksau ','marsekal ','tni ','yuyu ','sutisna ','mengatakan
# Generated: [ ['kepala ','staf '. " ], "'ksad'[ " ", ] marsekal') tni'"
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','- ','- ','pt ','golden ','energy ','mes ','tbk ','gems ','kantong ','pinjam ','besar ','us ','115 ','juta ','dari ','pt ','bank ','mandiri ','tbk ','bmri ','mayoritas ','raih ','dana ','itu ','akan ','beri ','kepada ','anak ','usaha ','pt ','borneo ','indobara ','bib ','sekretaris ','usaha ','golden ','energy ','sudin ','sh ','kata ','manajemen ','akan ','sunti ','dana ','segar ','kepada ','borneo ','indobara ','besar ','us ','65 ','juta ','untuk ','butuh ','belanja ','modal ','capital ','expenditure ', '
# Summary: [ ['pt ','golden ','energy ','mines ','tbk ','( ', '
# Generated: [ ['\ xa0 ','pt.'], "'golden '. pt ", \ steels. com '
# ====================================================================================================
# Review: ['bagi ','besar ','masyarakat ','indonesia ','pasti ','tahu ','serial ','keluarga ','cemara ','yang ','populer ','di ','era ','90 ','- ','an ','dan ','jadi ','salah ','satu ','serial ','baik ','yang ','selalu ','nanti ','para ','gemar ','serial ','keluarga ','yang ','tulis ','arswendo ','atmowiloto ','itu ','banyak ','jadi ','bagai ','panutan ','keluarga ','di ','indonesia ','untuk ','hidup ','keluarga ','dengan ','baik ','atas ','dasar ','itu ','rumah ','produksi ','visinema ','pictures ','ingin ','angkat ','konsep ','dasar ','cerita ','sebut ','ke ','medium ', '
# Summary: [ ['serial ', "'",'keluarga ','cemara ', "'",'yang ','populer
# Generated: [ ['\ xa0 ','bagi';'anda '.'netizen'], "'", [

# %%
df_reviews_test = pd.read_csv("/content/Test6.csv")
test_reviews = df_reviews_test['paragraphs'].values
test_sums = df_reviews_test['summary'].values

test_dataloader = DataLoader(test_reviews, test_sums, **dataloader_args)
test_dataset = test_dataloader.list_to_tensor_dataset(test_reviews, test_sums)
test_dataset = test_dataset.batch(training_config.batch_size)
pred_strs = []
gold_strs = []

for batched_input in tqdm(test_dataset):
    pred_str, gold_str, _ = batched_generate_summary(
        trained_bert2bert, 
        tokenizer, 
        batched_input
    )
    pred_strs.extend(pred_str)
    gold_strs.extend(gold_str)
    
rouge_output = rouge.compute(
    predictions=pred_strs,
    references=gold_strs,
    rouge_types=["rouge1","rouge2","rougeL"]
)
# Out:
#   0%|          | 0/236 [00:00<?, ?it/s]

# %%
print('Rouge report: ')
print("ROUGE 1 SCORE: ",rouge_output['rouge1'].mid)
print("ROUGE 2 SCORE: ",rouge_output['rouge2'].mid)
print("ROUGE F SCORE: ",rouge_output['rougeL'].mid)
# Out:
# Rouge report:
# ROUGE 1 SCORE:  Score(precision=0.11315715635891094, recall=0.1163013278144866, fmeasure=0.11274944480843527)
# ROUGE 2 SCORE:  Score(precision=0.017654985527792585, recall=0.018538138274980416, fmeasure=0.017640571667684908)
# ROUGE F SCORE:  Score(precision=0.10886073655212407, recall=0.11182454241664858, fmeasure=0.10846640461356388)

# %%
rouge_output
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.10863028064882164, recall=0.1117338089542043, fmeasure=0.10823050338899978), mid=Score(precision=0.11315715635891094, recall=0.1163013278144866, fmeasure=0.11274944480843527), high=Score(precision=0.11717519018505883, recall=0.1203916277436024, fmeasure=0.1166660712936658)),
#  'rouge2': AggregateScore(low=Score(precision=0.015729066458233142, recall=0.01664032239690135, fmeasure=0.015807783631248535), mid=Score(precision=0.017654985527792585, recall=0.018538138274980416, fmeasure=0.017640571667684908), high=Score(precision=0.01967730511041917, recall=0.020534923166502173, fmeasure=0.019557892654483613)),
#  'rougeL': AggregateScore(low=Score(precision=0.1049758200406128, recall=0.10804003379661369, fmeasure=0.10475922781304885), mid=Score(precision=0.10886073655212407, recall=0.11182454241664858, fmeasure=0.10846640461356388), high=Score(precision=0.1128706455839633, recall=0.11566896249462141, fmeasure=0.11222679308228033))}

# %%
# !cp -r /content/bert2bert-Checkpoint-epoch7-loss0.7590000033378601 "/content/drive/MyDrive"

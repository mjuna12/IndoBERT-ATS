# %%
# %%capture
# !pip install rouge_score
# !pip install datasets
# !pip install transformers
! pip install dill==0.3.6
import datasets
import transformers

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd 
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import transformers
from transformers import BertTokenizerFast, TFEncoderDecoderModel, AdamWeightDecay
from sklearn.model_selection import train_test_split

from tqdm.notebook import tqdm
from tensorflow.python.ops.numpy_ops import np_config
from pprint import pprint
""
# enable model saving at eager mode
np_config.enable_numpy_behavior()
print('transformers version:', transformers.__version__)
print('tensorflow version:', tf.__version__)
# Out:
# transformers version: 4.25.1
# tensorflow version: 2.9.2

# %%
df_reviews=pd.read_csv("/content/Experiment7.csv")
df_reviews.head()
# Out:
#    Unnamed: 0                                         paragraphs  \
# 0           0  [[['jakarta', ',', 'cnn', 'indonesia', '-', '-...
# 1           1  [[['selfie', 'ialah', 'salah', 'satu', 'tema',...
# 2           2  [[['jakarta', ',', 'cnn', 'indonesia', '-', '-...
# 3           3  [[['merdeka.com', '-', 'indonesia', 'corruptio...
# 4           4  [[['merdeka.com', '-', 'presiden', 'joko', 'wi...
#
#                                              summary
# 0  [['Dokter', 'Lula', 'Kamal', 'yang', 'merupaka...
# 1  [['Asus', 'memperkenalkan', '\xa0', 'ZenFone',...
# 2  [['Dinas', 'Pariwisata', 'Provinsi', 'Bengkulu...
# 3  [['Indonesia', 'Corruption', 'Watch', '(', 'IC...
# 4  [['Jokowi', 'memimpin', 'upacara', 'penurunan'...

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14262 entries, 0 to 14261
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  14262 non-null  int64
#  1   paragraphs  14262 non-null  object
#  2   summary     14262 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 334.4+ KB

# %%
import nltk #import library nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize #import word_tokenize for tokenizing text into words 
#word tokenization
def word_tokenization(s):
    tokens = word_tokenize(s)
    return tokens

df_reviews['paragraphs'] = df_reviews['paragraphs'].apply(word_tokenization).apply(str)
pd.DataFrame(df_reviews['paragraphs'])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#                                               paragraphs
# 0      ['[', '[', '[', "'jakarta", "'", ',', "'", ','...
# 1      ['[', '[', '[', "'selfie", "'", ',', "'ialah",...
# 2      ['[', '[', '[', "'jakarta", "'", ',', "'", ','...
# 3      ['[', '[', '[', "'merdeka.com", "'", ',', "'-"...
# 4      ['[', '[', '[', "'merdeka.com", "'", ',', "'-"...
# ...                                                  ...
# 14257  ['[', '[', '[', "'jakarta", "'", ',', "'", ','...
# 14258  ['[', '[', '[', "'bandung", "'", ',', "'", ','...
# 14259  ['[', '[', '[', "'jakarta", "'", ',', "'", '('...
# 14260  ['[', '[', '[', "'merdeka.com", "'", ',', "'-"...
# 14261  ['[', '[', '[', "'ada", "'", ',', "'satu", "'"...
#
# [14262 rows x 1 columns]

# %%
df_reviews.to_pickle('df.pkl')

# %%
df_reviews = pd.read_pickle('df.pkl')
df_reviews_sampled = df_reviews.copy()
# sampling n pairs of reviews and summarizies on shuffled dataframe
df_reviews_sampled = df_reviews_sampled.iloc[:40000, :]
df_reviews_sampled['text_len'] = df_reviews_sampled['paragraphs'].apply(lambda x: len(x.split()))
df_reviews_sampled['summary_len'] = df_reviews_sampled['summary'].apply(lambda x: len(x.split()))
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16,5))
ax[0].hist(df_reviews_sampled['text_len'])
ax[0].set_xticks(np.arange(0, max(df_reviews_sampled['text_len'])+1,250))
ax[0].set_title('Histogram of length of tokenized text')
ax[1].hist(df_reviews_sampled['summary_len'], color='yellow')
ax[1].set_xticks(np.arange(0, max(df_reviews_sampled['summary_len'])+1,5))
ax[1].set_title('Histogram of length of tokenized summary')
# Out:
# Text(0.5, 1.0, 'Histogram of length of tokenized summary')

# %%
class TrainingConfig:
    from_pt=True 
    val_split = 0.2
    pretrained_checkpoint = 'indolem/indobert-base-uncased'
    encoder_checkpoint = 'indolem/indobert-base-uncased'
    decoder_checkpoint = 'indolem/indobert-base-uncased'
    pad_token_id = 0
    shared_weight = False
    encoder_max_len = 256 
    decoder_max_len = 30 
    nb_epoch = 7 
    learning_rate = 3e-5 
    batch_size = 16
    
    
    def __init__(self, **kwargs):
        for k,v in kwargs.items():
            setattr(self, k, v)

# %%
class DataLoader:
    def __init__(self, paragraphs, summaries, **kwargs):
        self.paragraphs = paragraphs 
        self.summaries = summaries 
        self.tokenizer = kwargs.get('tokenizer')
        self.val_split = kwargs.get('val_split')
        self.encoder_max_len = kwargs.get('encoder_max_len')
        self.decoder_max_len = kwargs.get('decoder_max_len')
    
    @property
    def sample_size(self):
        assert len(self.paragraphs)==len(self.summaries)
        return len(self.paragraphs)
    
    def split_train_test(self):
        train_idx, val_idx = train_test_split(
            list(range(self.sample_size)), 
            test_size=self.val_split, 
            random_state=98
        )
        return train_idx, val_idx
    
    def convert_text_to_ids(self, input_paragraphs, input_summaries):
        inputs = self.tokenizer(
            list(input_paragraphs), 
            return_tensors='np', 
            padding='max_length', 
            truncation=True, 
            max_length=self.encoder_max_len
        )
        outputs = self.tokenizer(
            list(input_summaries), 
            return_tensors='np', 
            padding='max_length', 
            truncation=True, 
            max_length=self.decoder_max_len
        )
        return inputs, outputs
    
    def list_to_tensor_dataset(self, input_paragraphs, input_summaries):
        inputs, outputs = self.convert_text_to_ids(
            input_paragraphs, 
            input_summaries
        )
        input_ids = tf.data.Dataset.from_tensor_slices(
            inputs['input_ids']
        )
        attention_masks = tf.data.Dataset.from_tensor_slices(
            inputs['attention_mask']
        )
        output_ids = tf.data.Dataset.from_tensor_slices(
            outputs['input_ids']
        )
        output_attention_masks = tf.data.Dataset.from_tensor_slices(
            outputs['attention_mask']
        )                                                
        tf_dataset = tf.data.Dataset.zip(
            ({
                'input_ids': input_ids, 
                'attention_mask': attention_masks,
                'decoder_input_ids': output_ids, 
                 'decoder_attention_mask': output_attention_masks
            }, 
            output_ids)
        )
        return tf_dataset
    
    def __call__(self):
        train_idx, val_idx = self.split_train_test()
        train_paras, val_paras = self.paragraphs[train_idx], self.paragraphs[val_idx]
        train_sums, val_sums = self.summaries[train_idx], self.summaries[val_idx]
        train_dataset = self.list_to_tensor_dataset(train_paras, train_sums)
        val_dataset = self.list_to_tensor_dataset(val_paras, val_sums)
        return train_dataset, val_dataset

# %%
class Seq2SeqLoss(tf.keras.losses.Loss):
    def __init__(self, pad_token_id, name="seq2seq_loss"):
        super().__init__(name=name)
        self.pad_token_id = pad_token_id

    def call(self, y_true, y_pred):
        loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(
            from_logits=True, 
            reduction=tf.keras.losses.Reduction.NONE
        )
        # shift the label and output sequences to match  
        output_logits = y_pred[:,:-1,:]
        input_labels = y_true[:,1:] 
        loss = loss_fn(input_labels, output_logits)
        # calculate loss without the padding tokens in label sequence
        mask = tf.cast((input_labels != self.pad_token_id), dtype=tf.float32)
        loss = loss * mask
        return tf.reduce_sum(loss) / tf.reduce_sum(mask)

# %%
class Trainer:
    def __init__(self, model, loss_fn, optimizer, metric):
        self.model = model
        self.loss_fn = loss_fn
        self.optimizer = optimizer
        self.metric = metric
        # loss tracker will capture the mean of loss till now
        self.loss_tracker = tf.keras.metrics.Mean(name='mean_loss')
    
    # Training Step
    @tf.function 
    def train_step(self, inputs):
        input_seqs, input_labels = inputs
        with tf.GradientTape() as tape: 
            outputs = self.model(
                input_seqs['input_ids'],
                input_seqs['attention_mask'],
                input_seqs['decoder_input_ids'],
                input_seqs['decoder_attention_mask'],
                training = True
            )
            logits = outputs.logits
            loss = self.loss_fn(input_labels, logits)
        gradients = tape.gradient(loss, self.model.trainable_weights)
        self.optimizer.apply_gradients(
            zip(gradients, self.model.trainable_weights)
        )
        self.loss_tracker.update_state(loss)
#         self.metric.update_state(y, predictions)
        return loss
        
    # Validation Step
    @tf.function  
    def val_step(self, inputs):
        input_seqs, input_labels = inputs
        outputs = self.model(                
                input_seqs['input_ids'],
                input_seqs['attention_mask'],
                input_seqs['decoder_input_ids'],
                input_seqs['decoder_attention_mask'],
                training = False
        )
        logits = outputs.logits
        loss = self.loss_fn(input_labels, logits)
        self.loss_tracker.update_state(loss)
#         self.metric.update_state(y,predictions)
        return loss

# %%
def batched_generate_summary(model, tokenizer, batched_input):
    input_seqs, input_labels = batched_input
    outputs = model.generate(
        input_ids=input_seqs['input_ids'], 
        attention_mask=input_seqs['attention_mask']
    )
    output_strs = tokenizer.batch_decode(
        outputs, 
        skip_special_tokens=True
    )
    output_gold = tokenizer.batch_decode(
        input_seqs['decoder_input_ids'], 
        skip_special_tokens=True
    )
    input_strs = tokenizer.batch_decode(
        input_seqs['input_ids'], 
        skip_special_tokens=True
    )
    return output_strs, output_gold, input_strs

# %%
reviews = df_reviews_sampled['paragraphs'].values
summaries = df_reviews_sampled['summary'].values

training_config = TrainingConfig(nb_epoch=7)
tokenizer = BertTokenizerFast.from_pretrained(training_config.encoder_checkpoint)

dataloader_args = {
    'tokenizer': tokenizer,
    'val_split': training_config.val_split,
    'encoder_max_len': training_config.encoder_max_len,
    'decoder_max_len': training_config.decoder_max_len
}
dataloader = DataLoader(reviews, summaries, **dataloader_args)
train_dataset, val_dataset = dataloader()
train_dataset = (train_dataset
                 .shuffle(int(dataloader.sample_size*(1-training_config.val_split)))
                 .batch(training_config.batch_size))
val_dataset = val_dataset.batch(training_config.batch_size)
# Out:
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/234k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.01k [00:00<?, ?B/s]

# %%
model = transformers.EncoderDecoderModel.from_encoder_decoder_pretrained(
    training_config.encoder_checkpoint, 
    training_config.decoder_checkpoint,
    tie_encoder_decoder=training_config.shared_weight,from_pt=True)
# Out:
# Downloading:   0%|          | 0.00/445M [00:00<?, ?B/s]

# %%
model.save_pretrained('indolem/indobert-base-uncased')
model = TFEncoderDecoderModel.from_pretrained('/content/indolem/indobert-base-uncased',from_pt=True)

# %%
model.config.decoder_start_token_id = tokenizer.cls_token_id # 101
model.config.eos_token_id = tokenizer.sep_token_id # 102 
model.config.pad_token_id = tokenizer.pad_token_id # 0
model.config.vocab_size = model.config.encoder.vocab_size

# %%
model.config.max_length = 30
model.config.min_length = 3
model.config.no_repeat_ngram_size = 2
model.config.early_stopping = True
model.config.length_penalty = 2.0
model.config.num_beams = 4

# %%
#rouge = datasets.load_metric('rouge')
tf.keras.backend.clear_session()
trainer = Trainer(model=model,
                  loss_fn=Seq2SeqLoss(training_config.pad_token_id),
                  optimizer=AdamWeightDecay(
                      learning_rate=training_config.learning_rate, 
                      weight_decay_rate=0.005),
                  metric=None)

# %%
import datasets
rouge = datasets.load_metric("rouge")
for epoch in range(training_config.nb_epoch):
    print(f'\nEpoch {epoch+1}\n')
    print('Training....')
    for step,batched_input in enumerate(tqdm(train_dataset)):
        loss = trainer.train_step(batched_input)
        till_now_loss = trainer.loss_tracker.result()
        if step%200 == 0:
            print(f'Training loss for one batch at step {step}: {round(till_now_loss,3)}') 
    trainer.loss_tracker.reset_states()
    print('Validating....')
    val_measures = {'rouge precision':0, 'rouge recall':0, 'rouge f1': 0}
    for step, batched_input in enumerate(tqdm(val_dataset)):
        val_loss = trainer.val_step(batched_input)
    till_now_val_loss = trainer.loss_tracker.result()
    print(f'Validation loss: {round(till_now_val_loss,3)}')
    model.save_pretrained(
        f'bert2bert-Checkpoint-epoch{epoch+1}-loss{round(till_now_val_loss,3)}'
    )
    trainer.loss_tracker.reset_states()
# Out:
# <ipython-input-20-adafa7a0519c>:2: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   rouge = datasets.load_metric("rouge")
# Downloading builder script:   0%|          | 0.00/2.16k [00:00<?, ?B/s]
# Epoch 1
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# WARNING:tensorflow:Gradients do not exist for variables ['tf_encoder_decoder_model/encoder/bert/pooler/dense/kernel:0', 'tf_encoder_decoder_model/encoder/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_encoder_decoder_model/encoder/bert/pooler/dense/kernel:0', 'tf_encoder_decoder_model/encoder/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# Training loss for one batch at step 0: 10.102999687194824
# Training loss for one batch at step 200: 2.8589999675750732
# Training loss for one batch at step 400: 2.5399999618530273
# Training loss for one batch at step 600: 2.371999979019165
# WARNING:tensorflow:Gradients do not exist for variables ['tf_encoder_decoder_model/encoder/bert/pooler/dense/kernel:0', 'tf_encoder_decoder_model/encoder/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 1.843999981880188
#
# Epoch 2
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 1.7949999570846558
# Training loss for one batch at step 200: 1.7350000143051147
# Training loss for one batch at step 400: 1.621000051498413
# Training loss for one batch at step 600: 1.5360000133514404
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 1.2699999809265137
#
# Epoch 3
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 1.253999948501587
# Training loss for one batch at step 200: 1.1990000009536743
# Training loss for one batch at step 400: 1.1660000085830688
# Training loss for one batch at step 600: 1.1510000228881836
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 1.0980000495910645
#
# Epoch 4
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 1.062999963760376
# Training loss for one batch at step 200: 0.9390000104904175
# Training loss for one batch at step 400: 0.9350000023841858
# Training loss for one batch at step 600: 0.9200000166893005
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 0.9739999771118164
#
# Epoch 5
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 0.7429999709129333
# Training loss for one batch at step 200: 0.7289999723434448
# Training loss for one batch at step 400: 0.7260000109672546
# Training loss for one batch at step 600: 0.7210000157356262
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 0.8970000147819519
#
# Epoch 6
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 0.5040000081062317
# Training loss for one batch at step 200: 0.5479999780654907
# Training loss for one batch at step 400: 0.5540000200271606
# Training loss for one batch at step 600: 0.5569999814033508
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 0.8899999856948853
#
# Epoch 7
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 0.45100000500679016
# Training loss for one batch at step 200: 0.42100000381469727
# Training loss for one batch at step 400: 0.4300000071525574
# Training loss for one batch at step 600: 0.4320000112056732
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 0.8399999737739563

# %%
# from transformers import 
import datasets
rouge = datasets.load_metric("rouge")
trained_bert2bert = TFEncoderDecoderModel.from_pretrained("/content/bert2bert-Checkpoint-epoch7-loss0.8399999737739563")

# val0 = list(val_dataset.as_numpy_iterator())[0]
for step, batched_input in enumerate(tqdm(val_dataset)):
    pred_str, gold_str, input_strs = batched_generate_summary(
        trained_bert2bert, 
        tokenizer, 
        batched_input
    )
    rouge_output = rouge.compute(
        predictions=pred_str,
        references=gold_str,
        rouge_types=["rouge1","rouge2","rougeL"]
    )
    print('Rouge report: ')
    print("ROUGE 1 SCORE: ",rouge_output['rouge1'].mid)
    print("ROUGE 2 SCORE: ",rouge_output['rouge2'].mid)
    print("ROUGE F SCORE: ",rouge_output['rougeL'].mid)
    for p_str,g_str,in_str in zip(pred_str, gold_str, input_strs):
        print('='*100)
        print('Review: ' + in_str)
        print('Summary: ' + g_str)
        print('Generated: ' + p_str)
    
    break
# Out:
#   0%|          | 0/179 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/transformers/generation/tf_utils.py:1800: UserWarning: Neither `max_length` nor `max_new_tokens` have been set, `max_length` will default to 30 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Rouge report:
# ROUGE 1 SCORE:  Score(precision=0.24382440476190476, recall=0.23258928571428575, fmeasure=0.23629599567099566)
# ROUGE 2 SCORE:  Score(precision=0.07931547619047619, recall=0.071875, fmeasure=0.0745879120879121)
# ROUGE F SCORE:  Score(precision=0.23072916666666668, recall=0.22053571428571428, fmeasure=0.2229752886002886)
# ====================================================================================================
# Review: ['[ ','[ ','[ ', "'jakarta ", "'", ', ', "'", ', ', "'", ', ', "'cnn ", "'", ', ', "'indonesia ", "'", ', ', "'- ", "'", ', ', "'- ", "'", ', ', "'direktur ", "'", ', ', "'utama ", "'", ', ', "'pt ", "'", ', ', "'transjakarta ", "'", ', ', "'", ', ', "'", ', ', "'budi ", "'", ', ', "'kaliwono ", "'", ', ', "'meminta ", "'", ', ', "'maaf ", "'", ', ', "'kepada ", "'", ', ', "'pelanggan ", "'", ', ', "'terkait ", "'", ', ',
# Summary: [ ['\ xa0 ','direktur ','utama ','pt ','transjakarta ', ', ',
# Generated: [ ['direktur ','utama '.,.'], ].. ] ] \ xa0'budi'[.
# ====================================================================================================
# Review: ['[ ','[ ','[ ', "'jakarta ", "'", ', ', "'",'a¢a \ x80a \ x93 ', "'", ', ', "'putra ", "'", ', ', "'kedua ", "'", ', ', "'venna ", "'", ', ', "'melinda ", "'", ', ', "'", ', ', "'", ', ', "'athalla ", "'", ', ', "'naufal ", "'", ', ', "'", ', ', "'", ', ', "'mengalami ", "'", ', ', "'kecelakaan ", "'", ', ', "'pada ", "'", ', ', "'jumat ", "'", ', ', "'",'( ', "'", ', ', "'29 ", "'", ', ', "'/ ",
# Summary: [ ['putra ','kedua ','venna ','melinda ', ', ','athalla
# Generated: [ ['putra ','kandung'], "'",a'meliana'sekaligus'saburna'triana
# ====================================================================================================
# Review: ['[ ','[ ','[ ', "'jakarta ", "'", ', ', "'", ', ', "'", ', ', "'cnn ", "'", ', ', "'indonesia ", "'", ', ', "'- ", "'", ', ', "'- ", "'", ', ', "'tim ", "'", ', ', "'kuasa ", "'", ', ', "'hukum ", "'", ', ', "'gnpf ", "'", ', ', "'kapitra ", "'", ', ', "'ampera ", "'", ', ', "'menyebut ", "'", ', ', "'pentolan ", "'", ', ', "'front ", "'", ', ', "'pembela ", "'", ', ', "'islam ", "'", ', ', "'rizieq ", "'", ', '
# Summary: [ ['tim ','kuasa ','hukum ','gnpf ','kapitra ','ampera
# Generated: [ ['tim ','advokasi'], "'gnppgpfpmmf'\ xa0 '
# ====================================================================================================
# Review: ['[ ','[ ','[ ', "'lewat ", "'", ', ', "'permainan ", "'", ', ', "'baru ", "'", ', ', "'hitman ", "'", ', ', "'", ', ', "'", ', ', "'io ", "'", ', ', "'interactive ", "'", ', ', "'menebus ", "'", ', ', "'sejumlah ", "'", ', ', "'kekeliruan ", "'", ', ', "'pada ", "'", ', ', "'arahan ", "'", ', ', "'desain ", "'", ', ', "'hitman ", "'", ', ', "'",': ', "'", ', ', "'absolution ", "'", ', ', "'", '. ', "'",'] ', ', ','[ '
# Summary: [ ['lewat ','permainan ','baru ','hitman ', ', ','io ', '
# Generated: [ ['permainan ','nintendo'], "'", -'game'\ xa0'xbox'buku '
# ====================================================================================================
# Review: ['[ ','[ ','[ ', "'merdeka. com ", "'", ', ', "'- ", "'", ', ', "'seorang ", "'", ', ', "'ahli ", "'", ', ', "'cokelat ", "'", ', ', "'asal ", "'", ', ', "'swiss ", "'", ', ', "'telah ", "'", ', ', "'menciptakan ", "'", ', ', "'sebatang ", "'", ', ', "'cokelat ", "'", ', ', "'yang ", "'", ', ', "'diklaim ", "'", ', ', "'mampu ", "'", ', ', "'mengatasi ", "'", ', ', "'nyeri ", "'", ', ', "'haid ", "'", ', ', "'", '. ', "'",'] ', ',
# Summary: [ ['dilansir ','dailymail ', ', ','marc ','widmer ','seorang '
# Generated: [ ['ahli ','cokelat'], "'dr. a. com'",.'s \ xa0 '
# ====================================================================================================
# Review: ['[ ','[ ','[ ', "'jakarta ", "'", ', ', "'", ', ', "'", ', ', "'cnn ", "'", ', ', "'indonesia ", "'", ', ', "'- ", "'", ', ', "'- ", "'", ', ', "'ketua ", "'", ', ', "'komisi ", "'", ', ', "'ix ", "'", ', ', "'dpr ", "'", ', ', "'ri ", "'", ', ', "'dede ", "'", ', ', "'yusuf ", "'", ', ', "'macan ", "'", ', ', "'effendi ", "'", ', ', "'", ', ', "'", ', ', "'mengaku ", "'", ', ', "'telah ", "'", ', ', "
# Summary: [ ['ketua ','komisi ','ix ','dpr ','ri ','dede ','yusuf
# Generated: [ ['ketua ','komisi '.'pemberantasan'], [ "'bkp ", ’'” ’m '
# ====================================================================================================
# Review: ['[ ','[ ','[ ', "'singapura ", "'", ', ', "'", ', ', "'", ', ', "'cnn ", "'", ', ', "'indonesia ", "'", ', ', "'- ", "'", ', ', "'- ", "'", ', ', "'cerita ", "'", ', ', "'rakyat ", "'", ', ', "'dan ", "'", ', ', "'beragam ", "'", ', ', "'mitos ", "'", ', ', "'\ \ xa0 ", "'", ', ', "'bagi ", "'", ', ', "'masyarakat ", "'", ', ', "'asia ", "'", ', ', "'bukan ", "'", ', ', "'hal ", "'", ', ', "'yang ", "'", ', ', "
# Summary: [ ['cerita ','rakyat ','dan ','mitos ','bagi ','masyarakat ','asia
# Generated: [ ['cerita ','mengenai''.'kehidupan'], [ "'\ xa0 ", "g'"
# ====================================================================================================
# Review: ['[ ','[ ','[ ', "'jakarta ", "'", ', ', "'", ', ', "'", ', ', "'cnn ", "'", ', ', "'indonesia ", "'", ', ', "'- ", "'", ', ', "'- ", "'", ', ', "'gabungan ", "'", ', ', "'produsen ", "'", ', ', "'rokok ", "'", ', ', "'putih ", "'", ', ', "'indonesia ", "'", ', ', "'",'( ', "'", ', ', "'gaprindo ", "'", ', ', "'",') ', "'", ', ', "'mengaku ", "'", ', ', "'kecewa ", "'", ', ', "'dengan ", "'", ', ', "'keputusan ", "'",
# Summary: [ ['gabungan ','pengusaha ','rokok ','putih ','\ xa0 ','indonesia ',
# Generated: [ ['gabungan ','produsen'], rokok'di - '.'indonesia'[nto'tjah tjahaja '
# ====================================================================================================
# Review: ['[ ','[ ','[ ', "'jakarta ", "'", ', ', "'", ', ', "'", ', ', "'cnn ", "'", ', ', "'indonesia ", "'", ', ', "'- ", "'", ', ', "'- ", "'", ', ', "'menteri ", "'", ', ', "'hukum ", "'", ', ', "'dan ", "'", ', ', "'ham ", "'", ', ', "'", ', ', "'", ', ', "'yasonna ", "'", ', ', "'hamonangan ", "'", ', ', "'laoly ", "'", ', ', "'mengatakan ", "'", ', ', "'pihaknya ", "'", ', ', "'menunggu ", "'", ', ', "'undangan ", "'", '
# Summary: [ ['menkumham ','yasonna ','laoly ','mengatakan ','pihaknya ','menunggu
# Generated: [ ['menkumham ','nurmantyo'], "'", ’'memanggil'ham'laoly
# ====================================================================================================
# Review: ['[ ','[ ','[ ', "'ada ", "'", ', ', "'banyak ", "'", ', ', "'kamera ", "'", ', ', "'pengawas ", "'", ', ', "'yang ", "'", ', ', "'bisa ", "'", ', ', "'kita ", "'", ', ', "'gunakan ", "'", ', ', "'di ", "'", ', ', "'rumah ", "'", ', ', "'atau ", "'", ', ', "'kantor ", "'", ', ', "'untuk ", "'", ', ', "'meningkatkan ", "'", ', ', "'keamanan ", "'", ', ', "'", '. ', "'",'] ', ', ','[ ', "'harganya ", "'", ', ', "'beragam ", "'",
# Summary: [ ['sebuah ','solusi ','inovatif ','ditawarkan ','oleh ','tim ','ae
# Generated: [ ['kamera ','slirrr. p'], ] \ xa0 "'",.'an '
# ====================================================================================================
# Review: ['[ ','[ ','[ ', "'jakarta ", "'", ', ', "'", ', ', "'", ', ', "'cnn ", "'", ', ', "'indonesia ", "'", ', ', "'- ", "'", ', ', "'- ", "'", ', ', "'kim ", "'", ', ', "'kardashian ", "'", ', ', "'\ \ xa0 ", "'", ', ', "'akhirnya ", "'", ', ', "'memamerkan ", "'", ', ', "'foto ", "'", ', ', "'anak ", "'", ', ', "'ketiganya ", "'", ', ', "'", ', ', "'", ', ', "'chicago ", "'", ', ', "'west ", "'", ', ', "'", '. ', "
# Summary: [ ['kim ','kardashian ','akhirnya ','memamerkan ','foto ','anak ',
# Generated: [ ['kim ','kardashian'], [ akhirnya'kembali'bahkan ’ ’ ‘ ’'kanye ’ ′
# ====================================================================================================
# Review: ['[ ','[ ','[ ', "'suara. com ", "'", ', ', "'- ", "'", ', ', "'calon ", "'", ', ', "'gubernur ", "'", ', ', "'jawa ", "'", ', ', "'tengah ", "'", ', ', "'nomor ", "'", ', ', "'urut ", "'", ', ', "'",'2 ', "'", ', ', "'", ', ', "'", ', ', "'sudirman ", "'", ', ', "'said ", "'", ', ', "'pulang ", "'", ', ', "'kampung ", "'", ', ', "'menuju ", "'", ', ', "'tanah ", "'", ', ', "'kelahirannya ", "'", ', ', "'brebes ", "'", ', '
# Summary: [ ['calon ','gubernur ','jawa ','tengah ','nomor ','urut ','2
# Generated: [ ['calon ','gubernur '.'jawa'], ]. 000'000. 00'00 003'[
# ====================================================================================================
# Review: ['[ ','[ ','[ ', "'suara. com ", "'", ', ', "'- ", "'", ', ', "'bila ", "'", ', ', "'tak ", "'", ', ', "'segera ", "'", ', ', "'diselesaikan ", "'", ', ', "'", ', ', "'", ', ', "'konflik ", "'", ', ', "'kepengurusan ", "'", ', ', "'di ", "'", ', ', "'tubuh ", "'", ', ', "'partai ", "'", ', ', "'hanura ", "'", ', ', "'bakal ", "'", ', ', "'berdampak ", "'", ', ', "'besar ", "'", ', ', "'pada ", "'", ', ', "'keikutsertaannya ", "'", ', ', "
# Summary: [ ['bila ','tak ','segera ','diselesaikan ', ', ','konflik ','kepengurusan
# Generated: [ ['terkait ','dengan '.'persoalan'], [ "'", ’'pecah ’ ’ [. [
# ====================================================================================================
# Review: ['[ ','[ ','[ ', "'jakarta ", "'", ', ', "'", ', ', "'", ', ', "'cnn ", "'", ', ', "'indonesia ", "'", ', ', "'- ", "'", ', ', "'- ", "'", ', ', "'kepala ", "'", ', ', "'staf ", "'", ', ', "'tni ", "'", ', ', "'angkatan ", "'", ', ', "'udara ", "'", ', ', "'",'( ', "'", ', ', "'ksau ", "'", ', ', "'",') ', "'", ', ', "'marsekal ", "'", ', ', "'tni ", "'", ', ', "'yuyu ", "'", ', ', "'sutisna ", " '
# Summary: [ ['ksau ','marsekal ','tni ','yuyu ','sutisna ','mengatakan
# Generated: [ ['kepala ','staf'], "'ksaum'",n'halimu'/'tni '
# ====================================================================================================
# Review: ['[ ','[ ','[ ', "'jakarta ", "'", ', ', "'", ', ', "'", ', ', "'cnn ", "'", ', ', "'indonesia ", "'", ', ', "'- ", "'", ', ', "'- ", "'", ', ', "'pt ", "'", ', ', "'golden ", "'", ', ', "'energy ", "'", ', ', "'mines ", "'", ', ', "'tbk ", "'", ', ', "'",'( ', "'", ', ', "'gems ", "'", ', ', "'",') ', "'", ', ', "'mengantongi ", "'", ', ', "'pinjaman ", "'", ', ', "'sebesar ", "'", ', ', "'us ",'$ ',
# Summary: [ ['pt ','golden ','energy ','mines ','tbk ','( ', '
# Generated: [ ['golden ','tribute'], "'", s'\ xa0's.') '
# ====================================================================================================
# Review: ['[ ','[ ','[ ', "'sebagian ", "'", ', ', "'besar ", "'", ', ', "'masyarakat ", "'", ', ', "'indonesia ", "'", ', ', "'pasti ", "'", ', ', "'tahu ", "'", ', ', "'serial ", "'", ', ','` ` ', "'", "'' ", ', ', "'keluarga ", "'", ', ', "'cemara ", "'", ', ','` ` ', "'", "'' ", ', ', "'yang ", "'", ', ', "'populer ", "'", ', ', "'di ", "'", ', ', "'era ", "'", ', ','` ` ', "'", "'' ", ', ', "'90 ", "'", ', ', "'- ",
# Summary: [ ['serial ', "'",'keluarga ','cemara ', "'",'yang ','populer
# Generated: [ ['sebagian ','besar '.'masyarakat'], [lahlah'" "'hampir'terbayangkankan '

# %%
df_reviews_test = pd.read_csv("/content/Test7.csv")
test_reviews = df_reviews_test['paragraphs'].values
test_sums = df_reviews_test['summary'].values

test_dataloader = DataLoader(test_reviews, test_sums, **dataloader_args)
test_dataset = test_dataloader.list_to_tensor_dataset(test_reviews, test_sums)
test_dataset = test_dataset.batch(training_config.batch_size)
pred_strs = []
gold_strs = []

for batched_input in tqdm(test_dataset):
    pred_str, gold_str, _ = batched_generate_summary(
        trained_bert2bert, 
        tokenizer, 
        batched_input
    )
    pred_strs.extend(pred_str)
    gold_strs.extend(gold_str)
    
rouge_output = rouge.compute(
    predictions=pred_strs,
    references=gold_strs,
    rouge_types=["rouge1","rouge2","rougeL"]
)
# Out:
#   0%|          | 0/236 [00:00<?, ?it/s]

# %%
print('Rouge report: ')
print("ROUGE 1 SCORE: ",rouge_output['rouge1'].mid)
print("ROUGE 2 SCORE: ",rouge_output['rouge2'].mid)
print("ROUGE F SCORE: ",rouge_output['rougeL'].mid)
# Out:
# Rouge report:
# ROUGE 1 SCORE:  Score(precision=0.1445251290147625, recall=0.14134800384800467, fmeasure=0.14057225000738272)
# ROUGE 2 SCORE:  Score(precision=0.03936092335215144, recall=0.03764619883040947, fmeasure=0.037594187943658104)
# ROUGE F SCORE:  Score(precision=0.13879352785852012, recall=0.13547346902610147, fmeasure=0.1348951487680315)

# %%
rouge_output
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.1392936755820529, recall=0.1363913255360632, fmeasure=0.1356662592456908), mid=Score(precision=0.1445251290147625, recall=0.14134800384800467, fmeasure=0.14057225000738272), high=Score(precision=0.1499314763703719, recall=0.14683063403458252, fmeasure=0.145891607830785)),
#  'rouge2': AggregateScore(low=Score(precision=0.03612355206005531, recall=0.03470007088428159, fmeasure=0.03459497213425839), mid=Score(precision=0.03936092335215144, recall=0.03764619883040947, fmeasure=0.037594187943658104), high=Score(precision=0.042695404767274736, recall=0.040763113592060994, fmeasure=0.04073823172237679)),
#  'rougeL': AggregateScore(low=Score(precision=0.13348796189854834, recall=0.1303039796460861, fmeasure=0.1299643820310278), mid=Score(precision=0.13879352785852012, recall=0.13547346902610147, fmeasure=0.1348951487680315), high=Score(precision=0.1437231549278002, recall=0.14018752689805444, fmeasure=0.13951794721808888))}

# %%
# %%capture
# !pip install rouge_score
# !pip install datasets
# !pip install transformers
! pip install dill==0.3.6
import datasets
import transformers

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd 
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import transformers
from transformers import BertTokenizerFast, TFEncoderDecoderModel, AdamWeightDecay
from sklearn.model_selection import train_test_split

from tqdm.notebook import tqdm
from tensorflow.python.ops.numpy_ops import np_config
from pprint import pprint
""
# enable model saving at eager mode
np_config.enable_numpy_behavior()
print('transformers version:', transformers.__version__)
print('tensorflow version:', tf.__version__)
# Out:
# transformers version: 4.25.1
# tensorflow version: 2.9.2

# %%
df_reviews=pd.read_csv("/content/Experiment8.csv")
df_reviews.head()
# Out:
#    Unnamed: 0                                         paragraphs  \
# 0           0  jakarta cnn indonesia dokter ryan thamrin yang...
# 1           1  selfie ialah salah satu tema panas di kalang p...
# 2           2  jakarta cnn indonesia dinas pariwisata provins...
# 3           3  merdeka com indonesia corruption watch icw min...
# 4           4  merdeka com presiden joko widodo jokowi pimpin...
#
#                                              summary
# 0  dokter lula kamal yang merupakan selebriti sek...
# 1  asus memperkenalkan zenfone generasi keempat d...
# 2  dinas pariwisata provinsi bengkulu kembali men...
# 3  indonesia corruption watch icw meminta komisi ...
# 4  jokowi memimpin upacara penurunan bendera usai...

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14262 entries, 0 to 14261
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  14262 non-null  int64
#  1   paragraphs  14262 non-null  object
#  2   summary     14262 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 334.4+ KB

# %%
import nltk #import library nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize #import word_tokenize for tokenizing text into words 
#word tokenization
def word_tokenization(s):
    tokens = word_tokenize(s)
    return tokens

df_reviews['paragraphs'] = df_reviews['paragraphs'].apply(word_tokenization).apply(str)
pd.DataFrame(df_reviews['paragraphs'])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#                                               paragraphs
# 0      ['jakarta', 'cnn', 'indonesia', 'dokter', 'rya...
# 1      ['selfie', 'ialah', 'salah', 'satu', 'tema', '...
# 2      ['jakarta', 'cnn', 'indonesia', 'dinas', 'pari...
# 3      ['merdeka', 'com', 'indonesia', 'corruption', ...
# 4      ['merdeka', 'com', 'presiden', 'joko', 'widodo...
# ...                                                  ...
# 14257  ['jakarta', 'cnn', 'indonesia', 'amerika', 'se...
# 14258  ['bandung', 'cnn', 'indonesia', 'borneo', 'fc'...
# 14259  ['jakarta', 'pos', 'kota', 'a', 'komisi', 'ber...
# 14260  ['merdeka', 'com', 'buah', 'kabar', 'gembira',...
# 14261  ['ada', 'satu', 'perangkat', 'tarik', 'lain', ...
#
# [14262 rows x 1 columns]

# %%
df_reviews.to_pickle('df.pkl')

# %%
df_reviews = pd.read_pickle('df.pkl')
df_reviews_sampled = df_reviews.copy()
# sampling n pairs of reviews and summarizies on shuffled dataframe
df_reviews_sampled = df_reviews_sampled.iloc[:40000, :]
df_reviews_sampled['text_len'] = df_reviews_sampled['paragraphs'].apply(lambda x: len(x.split()))
df_reviews_sampled['summary_len'] = df_reviews_sampled['summary'].apply(lambda x: len(x.split()))
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16,5))
ax[0].hist(df_reviews_sampled['text_len'])
ax[0].set_xticks(np.arange(0, max(df_reviews_sampled['text_len'])+1,250))
ax[0].set_title('Histogram of length of tokenized text')
ax[1].hist(df_reviews_sampled['summary_len'], color='yellow')
ax[1].set_xticks(np.arange(0, max(df_reviews_sampled['summary_len'])+1,5))
ax[1].set_title('Histogram of length of tokenized summary')
# Out:
# Text(0.5, 1.0, 'Histogram of length of tokenized summary')

# %%
class TrainingConfig:
    from_pt=True 
    val_split = 0.2
    pretrained_checkpoint = 'indolem/indobert-base-uncased'
    encoder_checkpoint = 'indolem/indobert-base-uncased'
    decoder_checkpoint = 'indolem/indobert-base-uncased'
    pad_token_id = 0
    shared_weight = False
    encoder_max_len = 256 
    decoder_max_len = 30 
    nb_epoch = 7 
    learning_rate = 3e-5 
    batch_size = 16
    
    
    def __init__(self, **kwargs):
        for k,v in kwargs.items():
            setattr(self, k, v)

# %%
class DataLoader:
    def __init__(self, paragraphs, summaries, **kwargs):
        self.paragraphs = paragraphs 
        self.summaries = summaries 
        self.tokenizer = kwargs.get('tokenizer')
        self.val_split = kwargs.get('val_split')
        self.encoder_max_len = kwargs.get('encoder_max_len')
        self.decoder_max_len = kwargs.get('decoder_max_len')
    
    @property
    def sample_size(self):
        assert len(self.paragraphs)==len(self.summaries)
        return len(self.paragraphs)
    
    def split_train_test(self):
        train_idx, val_idx = train_test_split(
            list(range(self.sample_size)), 
            test_size=self.val_split, 
            random_state=98
        )
        return train_idx, val_idx
    
    def convert_text_to_ids(self, input_paragraphs, input_summaries):
        inputs = self.tokenizer(
            list(input_paragraphs), 
            return_tensors='np', 
            padding='max_length', 
            truncation=True, 
            max_length=self.encoder_max_len
        )
        outputs = self.tokenizer(
            list(input_summaries), 
            return_tensors='np', 
            padding='max_length', 
            truncation=True, 
            max_length=self.decoder_max_len
        )
        return inputs, outputs
    
    def list_to_tensor_dataset(self, input_paragraphs, input_summaries):
        inputs, outputs = self.convert_text_to_ids(
            input_paragraphs, 
            input_summaries
        )
        input_ids = tf.data.Dataset.from_tensor_slices(
            inputs['input_ids']
        )
        attention_masks = tf.data.Dataset.from_tensor_slices(
            inputs['attention_mask']
        )
        output_ids = tf.data.Dataset.from_tensor_slices(
            outputs['input_ids']
        )
        output_attention_masks = tf.data.Dataset.from_tensor_slices(
            outputs['attention_mask']
        )                                                
        tf_dataset = tf.data.Dataset.zip(
            ({
                'input_ids': input_ids, 
                'attention_mask': attention_masks,
                'decoder_input_ids': output_ids, 
                 'decoder_attention_mask': output_attention_masks
            }, 
            output_ids)
        )
        return tf_dataset
    
    def __call__(self):
        train_idx, val_idx = self.split_train_test()
        train_paras, val_paras = self.paragraphs[train_idx], self.paragraphs[val_idx]
        train_sums, val_sums = self.summaries[train_idx], self.summaries[val_idx]
        train_dataset = self.list_to_tensor_dataset(train_paras, train_sums)
        val_dataset = self.list_to_tensor_dataset(val_paras, val_sums)
        return train_dataset, val_dataset

# %%
class Seq2SeqLoss(tf.keras.losses.Loss):
    def __init__(self, pad_token_id, name="seq2seq_loss"):
        super().__init__(name=name)
        self.pad_token_id = pad_token_id

    def call(self, y_true, y_pred):
        loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(
            from_logits=True, 
            reduction=tf.keras.losses.Reduction.NONE
        )
        # shift the label and output sequences to match  
        output_logits = y_pred[:,:-1,:]
        input_labels = y_true[:,1:] 
        loss = loss_fn(input_labels, output_logits)
        # calculate loss without the padding tokens in label sequence
        mask = tf.cast((input_labels != self.pad_token_id), dtype=tf.float32)
        loss = loss * mask
        return tf.reduce_sum(loss) / tf.reduce_sum(mask)

# %%
class Trainer:
    def __init__(self, model, loss_fn, optimizer, metric):
        self.model = model
        self.loss_fn = loss_fn
        self.optimizer = optimizer
        self.metric = metric
        # loss tracker will capture the mean of loss till now
        self.loss_tracker = tf.keras.metrics.Mean(name='mean_loss')
    
    # Training Step
    @tf.function 
    def train_step(self, inputs):
        input_seqs, input_labels = inputs
        with tf.GradientTape() as tape: 
            outputs = self.model(
                input_seqs['input_ids'],
                input_seqs['attention_mask'],
                input_seqs['decoder_input_ids'],
                input_seqs['decoder_attention_mask'],
                training = True
            )
            logits = outputs.logits
            loss = self.loss_fn(input_labels, logits)
        gradients = tape.gradient(loss, self.model.trainable_weights)
        self.optimizer.apply_gradients(
            zip(gradients, self.model.trainable_weights)
        )
        self.loss_tracker.update_state(loss)
#         self.metric.update_state(y, predictions)
        return loss
        
    # Validation Step
    @tf.function  
    def val_step(self, inputs):
        input_seqs, input_labels = inputs
        outputs = self.model(                
                input_seqs['input_ids'],
                input_seqs['attention_mask'],
                input_seqs['decoder_input_ids'],
                input_seqs['decoder_attention_mask'],
                training = False
        )
        logits = outputs.logits
        loss = self.loss_fn(input_labels, logits)
        self.loss_tracker.update_state(loss)
#         self.metric.update_state(y,predictions)
        return loss

# %%
def batched_generate_summary(model, tokenizer, batched_input):
    input_seqs, input_labels = batched_input
    outputs = model.generate(
        input_ids=input_seqs['input_ids'], 
        attention_mask=input_seqs['attention_mask']
    )
    output_strs = tokenizer.batch_decode(
        outputs, 
        skip_special_tokens=True
    )
    output_gold = tokenizer.batch_decode(
        input_seqs['decoder_input_ids'], 
        skip_special_tokens=True
    )
    input_strs = tokenizer.batch_decode(
        input_seqs['input_ids'], 
        skip_special_tokens=True
    )
    return output_strs, output_gold, input_strs

# %%
reviews = df_reviews_sampled['paragraphs'].values
summaries = df_reviews_sampled['summary'].values

training_config = TrainingConfig(nb_epoch=7)
tokenizer = BertTokenizerFast.from_pretrained(training_config.encoder_checkpoint)

dataloader_args = {
    'tokenizer': tokenizer,
    'val_split': training_config.val_split,
    'encoder_max_len': training_config.encoder_max_len,
    'decoder_max_len': training_config.decoder_max_len
}
dataloader = DataLoader(reviews, summaries, **dataloader_args)
train_dataset, val_dataset = dataloader()
train_dataset = (train_dataset
                 .shuffle(int(dataloader.sample_size*(1-training_config.val_split)))
                 .batch(training_config.batch_size))
val_dataset = val_dataset.batch(training_config.batch_size)
# Out:
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/234k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.01k [00:00<?, ?B/s]

# %%
model = transformers.EncoderDecoderModel.from_encoder_decoder_pretrained(
    training_config.encoder_checkpoint, 
    training_config.decoder_checkpoint,
    tie_encoder_decoder=training_config.shared_weight,from_pt=True)
# Out:
# Downloading:   0%|          | 0.00/445M [00:00<?, ?B/s]

# %%
model.save_pretrained('indolem/indobert-base-uncased')
model = TFEncoderDecoderModel.from_pretrained('/content/indolem/indobert-base-uncased',from_pt=True)

# %%
model.config.decoder_start_token_id = tokenizer.cls_token_id # 101
model.config.eos_token_id = tokenizer.sep_token_id # 102 
model.config.pad_token_id = tokenizer.pad_token_id # 0
model.config.vocab_size = model.config.encoder.vocab_size

# %%
model.config.max_length = 30
model.config.min_length = 3
model.config.no_repeat_ngram_size = 2
model.config.early_stopping = True
model.config.length_penalty = 2.0
model.config.num_beams = 4

# %%
#rouge = datasets.load_metric('rouge')
tf.keras.backend.clear_session()
trainer = Trainer(model=model,
                  loss_fn=Seq2SeqLoss(training_config.pad_token_id),
                  optimizer=AdamWeightDecay(
                      learning_rate=training_config.learning_rate, 
                      weight_decay_rate=0.005),
                  metric=None)

# %%
import datasets
rouge = datasets.load_metric("rouge")
for epoch in range(training_config.nb_epoch):
    print(f'\nEpoch {epoch+1}\n')
    print('Training....')
    for step,batched_input in enumerate(tqdm(train_dataset)):
        loss = trainer.train_step(batched_input)
        till_now_loss = trainer.loss_tracker.result()
        if step%200 == 0:
            print(f'Training loss for one batch at step {step}: {round(till_now_loss,3)}') 
    trainer.loss_tracker.reset_states()
    print('Validating....')
    val_measures = {'rouge precision':0, 'rouge recall':0, 'rouge f1': 0}
    for step, batched_input in enumerate(tqdm(val_dataset)):
        val_loss = trainer.val_step(batched_input)
    till_now_val_loss = trainer.loss_tracker.result()
    print(f'Validation loss: {round(till_now_val_loss,3)}')
    model.save_pretrained(
        f'bert2bert-Checkpoint-epoch{epoch+1}-loss{round(till_now_val_loss,3)}'
    )
    trainer.loss_tracker.reset_states()
# Out:
# <ipython-input-20-adafa7a0519c>:2: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   rouge = datasets.load_metric("rouge")
# Downloading builder script:   0%|          | 0.00/2.16k [00:00<?, ?B/s]
# Epoch 1
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# WARNING:tensorflow:Gradients do not exist for variables ['tf_encoder_decoder_model/encoder/bert/pooler/dense/kernel:0', 'tf_encoder_decoder_model/encoder/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_encoder_decoder_model/encoder/bert/pooler/dense/kernel:0', 'tf_encoder_decoder_model/encoder/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# Training loss for one batch at step 0: 11.427000045776367
# Training loss for one batch at step 200: 7.556000232696533
# Training loss for one batch at step 400: 6.696000099182129
# Training loss for one batch at step 600: 6.190000057220459
# WARNING:tensorflow:Gradients do not exist for variables ['tf_encoder_decoder_model/encoder/bert/pooler/dense/kernel:0', 'tf_encoder_decoder_model/encoder/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 4.506999969482422
#
# Epoch 2
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 4.426000118255615
# Training loss for one batch at step 200: 4.460000038146973
# Training loss for one batch at step 400: 4.385000228881836
# Training loss for one batch at step 600: 4.328000068664551
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 3.9760000705718994
#
# Epoch 3
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 3.6640000343322754
# Training loss for one batch at step 200: 3.7170000076293945
# Training loss for one batch at step 400: 3.691999912261963
# Training loss for one batch at step 600: 3.6670000553131104
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 3.7339999675750732
#
# Epoch 4
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 3.046999931335449
# Training loss for one batch at step 200: 3.1500000953674316
# Training loss for one batch at step 400: 3.1670000553131104
# Training loss for one batch at step 600: 3.178999900817871
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 3.484999895095825
#
# Epoch 5
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 2.753999948501587
# Training loss for one batch at step 200: 2.7100000381469727
# Training loss for one batch at step 400: 2.697000026702881
# Training loss for one batch at step 600: 2.688999891281128
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 3.2809998989105225
#
# Epoch 6
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 2.546999931335449
# Training loss for one batch at step 200: 2.236999988555908
# Training loss for one batch at step 400: 2.23799991607666
# Training loss for one batch at step 600: 2.2279999256134033
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 3.0360000133514404
#
# Epoch 7
#
# Training....
#   0%|          | 0/714 [00:00<?, ?it/s]
# Training loss for one batch at step 0: 1.9700000286102295
# Training loss for one batch at step 200: 1.812999963760376
# Training loss for one batch at step 400: 1.8040000200271606
# Training loss for one batch at step 600: 1.8040000200271606
# Validating....
#   0%|          | 0/179 [00:00<?, ?it/s]
# Validation loss: 2.8440001010894775

# %%
# from transformers import 
import datasets
rouge = datasets.load_metric("rouge")
trained_bert2bert = TFEncoderDecoderModel.from_pretrained("/content/bert2bert-Checkpoint-epoch7-loss2.8440001010894775")

# val0 = list(val_dataset.as_numpy_iterator())[0]
for step, batched_input in enumerate(tqdm(val_dataset)):
    pred_str, gold_str, input_strs = batched_generate_summary(
        trained_bert2bert, 
        tokenizer, 
        batched_input
    )
    rouge_output = rouge.compute(
        predictions=pred_str,
        references=gold_str,
        rouge_types=["rouge1","rouge2","rougeL"]
    )
    print('Rouge report: ')
    print("ROUGE 1 SCORE: ",rouge_output['rouge1'].mid)
    print("ROUGE 2 SCORE: ",rouge_output['rouge2'].mid)
    print("ROUGE F SCORE: ",rouge_output['rougeL'].mid)
    for p_str,g_str,in_str in zip(pred_str, gold_str, input_strs):
        print('='*100)
        print('Review: ' + in_str)
        print('Summary: ' + g_str)
        print('Generated: ' + p_str)
    
    break
# Out:
#   0%|          | 0/179 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/transformers/generation/tf_utils.py:1800: UserWarning: Neither `max_length` nor `max_new_tokens` have been set, `max_length` will default to 30 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Rouge report:
# ROUGE 1 SCORE:  Score(precision=0.44508939631222244, recall=0.4742324625037011, fmeasure=0.45803264872223903)
# ROUGE 2 SCORE:  Score(precision=0.24294956140350876, recall=0.25708106034729317, fmeasure=0.2492057712528798)
# ROUGE F SCORE:  Score(precision=0.3936060014864362, recall=0.420922557305924, fmeasure=0.4050046075253906)
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','direktur ','utama ','pt ','transjakarta ','budi ','kaliwono ','minta ','maaf ','kepada ','langgan ','kait ','ganggu ','layan ','transjakarta ','di ','beberapa ','koridor ','yang ','sebab ','aksi ','karyawan ','tuntut ','naik ','gaji ','dan ','tetap ','status ','karyawan ','tetap ','senin ','kami ','rasa ','salah ','pada ','langgan ','karena ','ada ','ganggu ','ini ','kata ','budi ','saat ','temu ','di ','kantor ','yang ','ada ','di ','kawasan ','cawang ','jakarta ','timur ','budi ','kata ','tidak ','operasi ','ratus ','armada ','transjakarta '
# Summary: direktur utama pt transjakarta budi kaliwono meminta maaf kepada pelanggan terkait gangguan pelayanan transjakarta di beberapa koridor yang disebabkan aksi karyawan menuntut kenaikan gaji dan penetapan status
# Generated: direktur utama pt transjakarta budi setiawan meminta maaf kepada pengguna layanan transjakarta terkait sejumlah insiden di sejumlah rute yang menyebabkan mogok kerja karyawan dan karyawan mogok menuntut kenaikan
# ====================================================================================================
# Review: ['jakarta ','a ','putra ','dua ','venna ','melinda ','athalla ','naufal ','alami ','celaka ','pada ','jumat ','malam ','di ','kawasan ','jagakarsa ','jakarta ','selatan ','mobil ','yang ','kendara ','adik ','verrell ','bramasta ','itu ','hancur ','karena ','beberapa ','kali ','tabrak ','tiang ','meski ','kendara ','dalam ','kondiri ','ringsek ','untung ','athalla ','tak ','alami ','cedera ','serius ','sempat ','lari ','ke ','rumah ','sakit ','pondok ','indah ','namun ','athalla ','ungkap ','diri ','baik ','baik ','saja ','a ','jadi ','ini ',
# Summary: putra kedua venna melinda athalla naufal mengalami kecelakaan pada jumat malam di kawasan jagakarsa jakarta selatan mobil yang dikendarai
# Generated: putra sulung atalya nauwanda nikita naura mengalami kecelakaan pada jumat malam di kawasan cilandak jakarta selatan akibatnya mobil yang ditumpangi
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','tim ','kuasa ','hukum ','gnpf ','kapitra ','ampera ','sebut ','pentol ','front ','bela ','islam ','rizieq ','shihab ','saat ','ini ','ada ','di ','malaysia ','dia ','kata ','ada ','rizieq ','di ','malaysia ','beberapa ','hari ','usai ','laksana ','ibadah ','umrah ','di ','arab ','saudi ','kapitra ','kata ','rizieq ','di ','malaysia ','untuk ','konsultasi ','disertasi ','studi ','di ','malaysia ','dia ','sampai ','rizieq ','akan ','kembali ','ke ','indonesia ','pekan ','depan ','meski ','disertasi ','belum ','selesai ','ya ','lagi '
# Summary: tim kuasa hukum gnpf kapitra ampera menyebut pentolan front pembela islam rizieq shihab saat ini berada di malaysia dia mengatakan keberadaan rizieq di
# Generated: tim kuasa hukum gerakan pembela islam tpm mayor jenderal gatot nurmantyo menyebut pentolan fpi rizieq shihab saat ini berada di malaysia dia mengatakan
# ====================================================================================================
# Review: ['lewat ','main ','baru ','hitman ','io ','interactive ','tebus ','jumlah ','keliru ','pada ','arah ','desain ','hitman ','absolution ','di ','sana ','developer ','kembali ','gameplay ','sandbox ','ala ','blood ','money ','sila ','main ','eksplorasi ','dan ','tentu ','sendiri ','cara ','baik ','untuk ','selesai ','misi ','serta ','tak ','lupa ','suguh ','map ','tujuh ','kali ','lebih ','besar ','dari ','absolution ','namun ','hitman ','suguh ','lalu ','metode ','yang ','unik ','untuk ','pertama ','kali ','di ','franchise ','ini ','game ','lepas ','cara
# Summary: lewat permainan baru hitman io interactive menebus kekeliruan pada arahan desain hitman absolution developer mengembalikan gameplay sandbox ala blood money mempersilakan pemain
# Generated: hitman baru saja merilis salah satu permainan yang mencoba untuk meretas gameplay secara masif di android dan android secara keseluruhan game ini mencoba meretensi
# ====================================================================================================
# Review: ['merdeka ','com ','orang ','ahli ','cokelat ','asal ','swiss ','telah ','cipta ','batang ','cokelat ','yang ','klaim ','mampu ','atas ','nyeri ','haid ','tanya ','apakah ','makan ','sederhana ','cokelat ','benar ','benar ','bisa ','ringan ','rasa ','sakit ','menstruasi ','yang ','kadang ','bisa ','begitu ','tak ','tahan ','lansir ','dailymail ','marc ','widmer ','klaim ','kalau ','cokelat ','batang ','frauenmond ','yang ','dia ','kreasi ','bisa ','buat ','wanita ','yang ','sedang ','haid ','hindar ','dari ','nyeri ','dan ','kram ','perut ','cokelat ','ini ',
# Summary: dilansir dailymail marc widmer seorang ahli cokelat asal swiss mengklaim kalau cokelat batangan frauenmond yang dia kreasikan bisa membuat wanita
# Generated: seorang ahli cokelat asal swiss dilaporkan telah menciptakan cokelat yang diklaim dapat menyembuhkan nyeri otot haid yang kadang kadang bisa membuat nyeri punggung dan rasa sakit kadang benar
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','ketua ','komisi ','ix ','dpr ','ri ','dede ','yusuf ','macan ','effendi ','aku ','telah ','minta ','partai ','demokrat ','siap ','diri ','untuk ','masuk ','dalam ','bursa ','nama ','calon ','gubernur ','dalam ','pilgub ','jawa ','barat ','pilgub ','masih ','dinamis ','saya ','masih ','minta ','oleh ','partai ','untuk ','siap ','diri ','saya ','dan ','keluarga ','masih ','lihat ','dulu ','apakah ','saat ','ini ','memang ','sangat ','butuh ','oleh ','rakyat ','jawa ','barat ','atau ','tidak ','ujar ','dede ','yusuf ','seperti '
# Summary: ketua komisi ix dpr ri dede yusuf macan effendi mengaku telah diminta partai demokrat mempersiapkan diri untuk masuk dalam bursa nama calon gubernur dalam pilgub jawa barat
# Generated: ketua fraksi demokrat dede yusuf mengaku telah meminta macan effendi untuk mencalonkan diri dalam pilgub jawa barat dalam pencalonan tersebut ia mengaku siap untuk masuk dalam dalam
# ====================================================================================================
# Review: ['singapura ','cnn ','indonesia ','cerita ','rakyat ','dan ','agam ','mitos ','bagi ','masyarakat ','asia ','bukan ','hal ','yang ','baru ','akrab ','ini ','yang ','tangkap ','oleh ','jumlah ','sutradara ','di ','asia ','masuk ','joko ','anwar ','dari ','indonesia ','untuk ','jadi ','buah ','serial ','televisi ','tajuk ','folklore ','selain ','joko ','anwar ','serial ','yang ','payung ','hbo ','asia ','ini ','gandeng ','sutradara ','asal ','singapura ','eric ','khoo ','yang ','sekaligus ','cipta ','seri ','sebut ','lalu ','ada ','ho ','yuhang ','dari ','malaysia '
# Summary: cerita rakyat dan mitos bagi masyarakat asia digarap sejumlah sutradara termasuk joko anwar dari indonesia untuk menjadi sebuah serial bertajukfolklore selain joko anwar serial
# Generated: cerita rakyat rakyat china dan asia tenggara bukan hanya bagian dari serial drama populer yang digarap oleh sutradara joko anwar untuk itu ada juga film yang diadaptasi dari
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','gabung ','produsen ','rokok ','putih ','indonesia ','gaprindo ','aku ','kecewa ','dengan ','putus ','perintah ','yang ','kerek ','tarif ','pajak ','tambah ','nilai ','ppn ','hasil ','tembakau ','dari ','persen ','jadi ','persen ','ketua ','umum ','gaprindo ','muhaimin ','moeftie ','kata ','benar ','rencana ','naik ','sudah ','tahu ','asosiasi ','sejak ','agustus ','lalu ','kala ','diskus ','dengan ','badan ','bijak ','fiskal ','bkf ','menteri ','uang ','hanya ','saja ','diskusi ','saat ','itu ','rumus ','naik ','tarif ','ppn ','hasil ',
# Summary: gabungan pengusaha rokok putih indonesia gaprindo mengaku kecewa dengan keputusan pemerintah yang mengerek tarif ppn hasil tembakau dari persen menjadi persen memang awalnya rencana kenaikan
# Generated: bergabungnya produsen rokok merah putih pt rokok indonesia mengaku kecewa dengan keputusan pemerintah yang menaikkan tarif cukai rokok menjadi persen dari persen ketua komisi xi dpr ri
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','menteri ','hukum ','dan ','ham ','yasonna ','hamonangan ','laoly ','kata ','pihak ','tunggu ','undang ','badan ','legislasi ','dpr ','untuk ','bicara ','revisi ','undang ','undang ','mpr ','dpr ','dpd ','dprd ','dia ','harap ','baleg ','dpr ','segera ','undang ','kemenkumham ','agar ','revisi ','uu ','dapat ','cepat ','selesai ','a ','saya ','tunggu ','undang ','dari ','baleg ','kalau ','perlu ','segera ','a ','ujar ','yasonna ','di ','kantor ','kemenkumham ','jakarta ','sabtu ','malam ','yasonna ','tunggu ','undang ', '
# Summary: menkumham yasonna laoly mengatakan pihaknya menunggu undangan baleg dpr untuk membicarakan revisi undang undang dia berharap baleg dpr segera mengundang kemenkum
# Generated: menteri hukum dan hak asasi manusia yasonna laoly mengatakan pihaknya mempersilakan pihak dpr untuk membuka pembahasan rancangan undang undang badan legislasi dpr melalui dpr dia meminta
# ====================================================================================================
# Review: ['ada ','banyak ','kamera ','awas ','yang ','bisa ','kita ','guna ','di ','rumah ','atau ','kantor ','untuk ','tingkat ','aman ','harga ','agam ','gantung ','dari ','canggih ','serta ','lengkap ','fiturnya ','namun ','lemah ','besar ','kamera ','cctv ','standar ','letak ','pada ','a ','titik ','butaa ','karena ','perangkat ','ini ','paut ','di ','satu ','posisi ','solusi ','anda ','harus ','pakai ','lebih ','dari ','satu ','unit ','buah ','solusi ','inovatif ','tawar ','oleh ','tim ','aevena ','dengan ','ide ','yang ','adopsi ','dari ','perangkat ',
# Summary: sebuah solusi inovatif ditawarkan oleh tim aevena dengan ide yang diadopsi dari perangkat spesialis videography udara drone untuk membantu mengamankan tempat tinggal
# Generated: ae aeda adalah sebuah kamera yang dirancang untuk membantu pengguna yang ingin menggunakan kamera ini dengan mudah dan akurat tanpa merusak gambar salah satu fitur yang dimiliki
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','kim ','kardashian ','akhir ','pamer ','foto ','anak ','tiga ','chicago ','west ','senin ','kemarin ','kim ','unggah ','foto ','sama ','chicago ','ke ','instagram ','meski ','beri ','pula ','efek ','telinga ','dan ','hidung ','lucu ','itu ','rupa ','pertama ','kali ','publik ','bisa ','lihat ','foto ','chicago ','yang ','kini ','usia ','enam ','minggu ','telah ','lahir ','dari ','ibu ','ganti ','bayi ','chicago ','sederhana ','itu ','kim ','tulis ','terang ','foto ','dalam ','foto ','itu ','sang ','istri ','kanye '
# Summary: kim kardashian akhirnya memamerkan foto anak ketiganya chicago west senin kemarin kim mengunggah fotonya bersama chicago ke instagram meski diberi pula efek telinga
# Generated: kim kardashian akhirnya memamerkan koleksi foto anak keduanya bersama anak perempuannya chicago lewat akun instagramnya meski begitu sang bocah masih bisa tersenyum dan
# ====================================================================================================
# Review: ['suara ','com ','calon ','gubernur ','jawa ','tengah ','nomor ','urut ','sudirman ','said ','pulang ','kampung ','tuju ','tanah ','lahir ','brebes ','lantar ','kembali ','terjang ','banjir ','minggu ','sudirman ','unjung ','tempat ','tampung ','ungsi ','di ','desa ','kecipir ','dan ','losari ','untuk ','lihat ','sedia ','stok ','pangan ','para ','ungsi ','meski ','menu ','ada ','seperti ','ikan ','asin ','dan ','sambal ','dan ','tempe ','semangat ','warga ','masih ','tinggi ','untuk ','tahan ','kata ','sudirman ','pasang ','cawagub ','jateng ','ida ','fauziyah '
# Summary: calon gubernur jawa tengah nomor urut sudirman said pulang kampung menuju tanah kelahirannya brebes lantaran kembali diterjang banjir minggu pasangan cawagub jateng ida fauziyah ini
# Generated: calon gubernur jawa tengah sudirman said pulang kampung halamannya menuju tanah suci brebes menyusul banjir tanah longsor susulan di kediamannya di desa carik desa winongan kecamatan
# ====================================================================================================
# Review: ['suara ','com ','bila ','tak ','segera ','selesai ','konflik ','urus ','di ','tubuh ','partai ','hanura ','bakal ','dampak ','besar ','pada ','keikutsertaannya ','di ','milu ','sebab ','hanura ','bisa ','ancam ','tidak ','lolos ','verifikasi ','partai ','politik ','lantar ','saat ','ini ','jadi ','pecah ','urus ','kalau ','parpol ','itu ','tidak ','bisa ','sesuai ','tidak ','bisa ','tentu ','siapa ','tum ','siapa ','sekjennya ','ya ','mereka ','akan ','punya ','resiko ','tidak ','akan ','bisa ','lolos ','di ','dalam ','verifikasi ','faktual ','kata ','mantan ',
# Summary: bila tak segera diselesaikan konflik kepengurusan di tubuh partai hanura bakal berdampak besar pada keikutsertaannya di pemilu sebab hanura bisa terancam tidak lolos verifikasi partai politik lantaran
# Generated: bila tak segera diselesaikan masalah di tubuh partai hanura bakal berdampak besar di bawaslu pasalnya jika lolos verifikasi maka bisa terancam terancam tak lolos ke pemilu
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','kepala ','staf ','tni ','angkat ','udara ','ksau ','marsekal ','tni ','yuyu ','sutisna ','kata ','rencana ','beli ','pesawat ','tempur ','generasi ','sukhoi ','dari ','perintah ','rusia ','masih ','terus ','jalan ','sukhoi ','masih ','jalan ','tidak ','ada ','pengaruh ','apa ','apa ','sesuai ','dengan ','apa ','yang ','sampai ','panglima ','tni ','marsekal ','tni ','had ','tjahjanto ','kata ','yuyu ','usai ','rapat ','pimpin ','rapim ','tni ','angkat ','udara ','di ','cilangkap ','jakarta ','timur ','jumat ','seperti ','kutip ','antara
# Summary: ksau marsekal tni yuyu sutisna mengatakan rencana pembelian pesawat tempur generasi sukhoi dari pemerintah rusia masih terus berjalan ksau mengatakan hal itu menanggapi
# Generated: kepala staf angkatan udara ksau marsekal tni yuyuyu sutisno mengatakan rencana pembelian pesawat tempur sukhoi dari rusia masih berjalan meski masih ada jalan
# ====================================================================================================
# Review: ['jakarta ','cnn ','indonesia ','pt ','golden ','energy ','mes ','tbk ','gems ','kantong ','pinjam ','besar ','us ','juta ','dari ','pt ','bank ','mandiri ','tbk ','bmri ','mayoritas ','raih ','dana ','itu ','akan ','beri ','kepada ','anak ','usaha ','pt ','borneo ','indobara ','bib ','sekretaris ','usaha ','golden ','energy ','sudin ','sh ','kata ','manajemen ','akan ','sunti ','dana ','segar ','kepada ','borneo ','indobara ','besar ','us ','juta ','untuk ','butuh ','belanja ','modal ','capital ','expenditure ','capex ','bagi ','salah ','satu ',
# Summary: pt golden energy mines tbk gems mengantongi pinjaman sebesar us juta dari pt bank mandiri tbk bmri mayoritas raihan dana itu akan diberikan kepada anak
# Generated: pt golden steel group group mengucurkan kucuran kredit sebesar us juta dari pt bank rakyat indonesia bsp senilai rp triliun untuk bmp anak usahanya pt simpan
# ====================================================================================================
# Review: ['bagi ','besar ','masyarakat ','indonesia ','pasti ','tahu ','serial ','keluarga ','cemara ','yang ','populer ','di ','era ','an ','dan ','jadi ','salah ','satu ','serial ','baik ','yang ','selalu ','nanti ','para ','gemar ','serial ','keluarga ','yang ','tulis ','arswendo ','atmowiloto ','itu ','banyak ','jadi ','bagai ','panutan ','keluarga ','di ','indonesia ','untuk ','hidup ','keluarga ','dengan ','baik ','atas ','dasar ','itu ','rumah ','produksi ','visinema ','pictures ','ingin ','angkat ','konsep ','dasar ','cerita ','sebut ','ke ','medium ','yang ','lebih ', '
# Summary: serial keluarga cemara yang populer di era an kini akan diangkat ke layar lebar karakter abah dan emak yang ikonik nantinya doperankan ringgo agus rahman
# Generated: bagi anda yang belum mengenal keluarga pasti mengenal serial keluarga cemara di indonesia serial yang diangkat oleh rumah produksi keluarga indonesia itu mengangkat tema keluarga dalam bingkai keluarga

# %%
df_reviews_test = pd.read_csv("/content/Test8.csv")
test_reviews = df_reviews_test['paragraphs'].values
test_sums = df_reviews_test['summary'].values

test_dataloader = DataLoader(test_reviews, test_sums, **dataloader_args)
test_dataset = test_dataloader.list_to_tensor_dataset(test_reviews, test_sums)
test_dataset = test_dataset.batch(training_config.batch_size)
pred_strs = []
gold_strs = []

for batched_input in tqdm(test_dataset):
    pred_str, gold_str, _ = batched_generate_summary(
        trained_bert2bert, 
        tokenizer, 
        batched_input
    )
    pred_strs.extend(pred_str)
    gold_strs.extend(gold_str)
    
rouge_output = rouge.compute(
    predictions=pred_strs,
    references=gold_strs,
    rouge_types=["rouge1","rouge2","rougeL"]
)
# Out:
#   0%|          | 0/236 [00:00<?, ?it/s]

# %%
print('Rouge report: ')
print("ROUGE 1 SCORE: ",rouge_output['rouge1'].mid)
print("ROUGE 2 SCORE: ",rouge_output['rouge2'].mid)
print("ROUGE F SCORE: ",rouge_output['rougeL'].mid)
# Out:
# Rouge report:
# ROUGE 1 SCORE:  Score(precision=0.18311884681570384, recall=0.17690646203157062, fmeasure=0.17938253221910846)
# ROUGE 2 SCORE:  Score(precision=0.04568649487040655, recall=0.04408528051787429, fmeasure=0.04473560308519667)
# ROUGE F SCORE:  Score(precision=0.1472917320037419, recall=0.14214545432663483, fmeasure=0.1442190292196845)

# %%
rouge_output
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.17994209299039882, recall=0.1738462742439699, fmeasure=0.17630010760167092), mid=Score(precision=0.18311884681570384, recall=0.17690646203157062, fmeasure=0.17938253221910846), high=Score(precision=0.18640870580530292, recall=0.18000427274041433, fmeasure=0.18243882051116292)),
#  'rouge2': AggregateScore(low=Score(precision=0.04369391274242796, recall=0.04216198914897865, fmeasure=0.04278111582994189), mid=Score(precision=0.04568649487040655, recall=0.04408528051787429, fmeasure=0.04473560308519667), high=Score(precision=0.04766498009860401, recall=0.04588414857076837, fmeasure=0.04664520577934376)),
#  'rougeL': AggregateScore(low=Score(precision=0.14472760845494503, recall=0.1395265694143648, fmeasure=0.1416565081794838), mid=Score(precision=0.1472917320037419, recall=0.14214545432663483, fmeasure=0.1442190292196845), high=Score(precision=0.14980210781544887, recall=0.1446529375946403, fmeasure=0.14671248404271967))}
